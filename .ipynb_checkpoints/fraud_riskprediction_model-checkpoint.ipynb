# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.externals import joblib

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core import Workspace
from azureml.core.model import Model
from azureml.core import Experiment
from azureml.core.webservice import Webservice
from azureml.core.image import ContainerImage
from azureml.core.webservice import AciWebservice
from azureml.core.conda_dependencies import CondaDependencies

import collections
from sklearn.model_selection import train_test_split
import pickle as pkl
import logging
import azureml.dataprep as dprep 
from azureml.core import Dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2dbc2e1410ce> in <module>
#      12 from azureml.core.experiment import Experiment
#      13 from azureml.core.workspace import Workspace
# ---> 14 from azureml.train.automl import AutoMLConfig
#      15 from azureml.core import Workspace
#      16 from azureml.core.model import Model
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/__init__.py in <module>
#      23     # Suppress the warnings at the import phase.
#      24     warnings.simplefilter("ignore")
# ---> 25     from ._automl import fit_pipeline
#      26     from .automlconfig import AutoMLConfig
#      27     from .automl_step import AutoMLStep, AutoMLStepRun
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/_automl.py in <module>
#      17 from automl.client.core.runtime.cache_store import CacheStore
#      18 from automl.client.core.runtime import logging_utilities as runtime_logging_utilities
# ---> 19 from azureml.automl.core import data_transformation, fit_pipeline as fit_pipeline_helper
#      20 from azureml.automl.core.automl_pipeline import AutoMLPipeline
#      21 from azureml.automl.core.data_context import RawDataContext, TransformedDataContext
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/automl/core/fit_pipeline.py in <module>
#      18 from automl.client.core.common.limit_function_call_exceptions import TimeoutException
#      19 from automl.client.core.runtime.datasets import DatasetBase
# ---> 20 from . import package_utilities, pipeline_run_helper, training_utilities
#      21 from .automl_base_settings import AutoMLBaseSettings
#      22 from .automl_pipeline import AutoMLPipeline
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/automl/core/pipeline_run_helper.py in <module>
#      18 from automl.client.core.common.exceptions import ClientException
#      19 from automl.client.core.runtime import metrics
# ---> 20 from automl.client.core.runtime import pipeline_spec as pipeline_spec_module
#      21 from automl.client.core.runtime.datasets import DatasetBase
#      22 from automl.client.core.runtime.execution_context import ExecutionContext
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/automl/core/_vendor/automl/client/core/runtime/pipeline_spec.py in <module>
#      21
#      22 from automl.client.core.common import constants
# ---> 23 from automl.client.core.runtime import model_wrappers, tf_wrappers
#      24 from automl.client.core.runtime.nimbus_wrappers import AveragedPerceptronBinaryClassifier, \
#      25     AveragedPerceptronMulticlassClassifier, NimbusMlClassifierMixin, NimbusMlRegressorMixin
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/automl/core/_vendor/automl/client/core/runtime/tf_wrappers.py in <module>
#      34 os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#      35 if tf_found:
# ---> 36     tf.logging.set_verbosity(tf.logging.ERROR)
#      37
#      38     OPTIMIZERS = {
#
# AttributeError: module 'tensorflow' has no attribute 'logging'

# %%
#pip install -U tensorflow-gpu==1.14.0 tensorflow==estimator==1.14.0
# Out:
# Collecting tensorflow-gpu==1.14.0
#   Using cached https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting tensorflow==estimator==1.14.0
#   ERROR: Could not find a version that satisfies the requirement tensorflow==estimator==1.14.0 (from versions: 0.12.1, 1.0.0, 1.0.1, 1.1.0rc0, 1.1.0rc1, 1.1.0rc2, 1.1.0, 1.2.0rc0, 1.2.0rc1, 1.2.0rc2, 1.2.0, 1.2.1, 1.3.0rc0, 1.3.0rc1, 1.3.0rc2, 1.3.0, 1.4.0rc0, 1.4.0rc1, 1.4.0, 1.4.1, 1.5.0rc0, 1.5.0rc1, 1.5.0, 1.5.1, 1.6.0rc0, 1.6.0rc1, 1.6.0, 1.7.0rc0, 1.7.0rc1, 1.7.0, 1.7.1, 1.8.0rc0, 1.8.0rc1, 1.8.0, 1.9.0rc0, 1.9.0rc1, 1.9.0rc2, 1.9.0, 1.10.0rc0, 1.10.0rc1, 1.10.0, 1.10.1, 1.11.0rc0, 1.11.0rc1, 1.11.0rc2, 1.11.0, 1.12.0rc0, 1.12.0rc1, 1.12.0rc2, 1.12.0, 1.12.2, 1.12.3, 1.13.0rc0, 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0)
# ERROR: No matching distribution found for tensorflow==estimator==1.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# data_df = pd.read_csv('data/AI_ML_OrderExport_0812_v1.csv')
#test_df= pd.read_csv('data/AI_ML_OrderExport_0801_0810.csv')

data_df = pd.read_csv('data/Training_AI_ML_OrderExport_0701_0930_v2.csv')
test_df= pd.read_csv('data/Test_AI_ML_OrderExport_1001_1014_v2.csv')
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (58,59,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_df.head()
# Out:
#      ORDER_ID ORDER_CREATED_DATE  ACCOUNT_NUMBER  FRAUDNET_SCORE  TOTAL_PRICE  \
# 0  3665188023  7/1/2019 0:01      2241841849     200.00          847.92
# 1  1234842127  7/1/2019 0:06      615816905      nan             129.96
# 2  267822129   7/1/2019 0:06      1695230204     nan             1099.84
# 3  1610563078  7/1/2019 0:04      4199903225     nan             834.36
# 4  3936597081  7/1/2019 0:02      61538537       200.00          0.00
#
#                     SKU  TYPE1     MAKE1        MODEL1 PRICE1  \
# 0  ["190198776563"]      Phone  Apple     iPhone XR    649.99
# 1  ["723755019478"]      Phone  Motorola  moto e5 play 119.99
# 2  ["887276283197"]      Phone  Samsung   Galaxy Note9 999.99
# 3  ["652810832595"]      Phone  LG        G8 ThinQTM   779.99
# 4  ["APLIPHONE6GRAY16"]  Phone  Apple     iPhone 6     0.00
#
#             ...            ACTIVE_WATCH_RESULT FINAL_RESULT  \
# 0           ...             GREEN               GREEN
# 1           ...             GREEN               GREEN
# 2           ...             GREEN               GREEN
# 3           ...             GREEN               GREEN
# 4           ...             GREEN               GREEN
#
#   FINAL_RESULT_SOURCE   AW_REASON HOUR_OF_DAY SENT_TO_ACTIVE_WATCH_TIMESTAMP  \
# 0  ACTIVEWATCH         good_order  0           7/1/2019 0:07
# 1  ACTIVEWATCH         good_order  0           7/1/2019 0:08
# 2  ACTIVEWATCH         good_order  0           7/1/2019 0:18
# 3  ACTIVEWATCH         good_order  0           7/1/2019 0:11
# 4  ACTIVEWATCH         good_order  0           7/1/2019 0:39
#
#   ACTIVE_WATCH_TS  ORDER_SUBMIT_TS ACTIVE_WATCH_DURATION_MINS  \
# 0  NaN             7/1/2019 0:20   nan
# 1  NaN             7/1/2019 0:20   nan
# 2  7/1/2019 0:33   7/1/2019 0:35   14.65
# 3  7/1/2019 0:33   7/1/2019 0:35   21.92
# 4  NaN             7/1/2019 0:50   nan
#
#   ORDER_HOLD_DURATION_MINS
# 0 12.65
# 1 12.12
# 2 16.87
# 3 24.13
# 4 10.75
#
# [5 rows x 87 columns]

# %%
data=data_df[['TOTAL_PRICE','THIRD_PARTY_ID_SCORE','IS_EXISTING_CUSTOMER','NUM_PORTIN','FIRST_PARTY_ID_SCORE','ONETIMECHARGE','INSTALLMENT_AMOUNT','DEVICE_AT_HOME','FRAUDNET_SCORE','NUM_BYOD','IDA_RESULT','ALLOWED_LINES','MONTHLYRECURRINGCHARGE','EXTERNAL_CREDIT_CHECK_DONE','SALES_CHANNEL','EXTERNAL_APPROVED_LINES','APPROVED_LINES','ACNT_BILL_LNAME_MATCHES','ACNT_SHIP_FNAME_MATCHES','ACNT_SHIP_LNAME_MATCHES','SHIP_BILL_FNAME_MATCHES','BILL_SHIP_ADDR_MATCHES','MAKE1','MAKE2','MAKE3','MAKE4','MAKE5','MODEL1','MODEL2','MODEL3','MODEL4','MODEL5','PRICE1','PRICE2','PRICE3','PRICE4','PRICE5','HOUR_OF_DAY','FINAL_RESULT']]
test_data=test_df[['TOTAL_PRICE','THIRD_PARTY_ID_SCORE','IS_EXISTING_CUSTOMER','NUM_PORTIN','FIRST_PARTY_ID_SCORE','ONETIMECHARGE','INSTALLMENT_AMOUNT','DEVICE_AT_HOME','FRAUDNET_SCORE','NUM_BYOD','IDA_RESULT','ALLOWED_LINES','MONTHLYRECURRINGCHARGE','EXTERNAL_CREDIT_CHECK_DONE','SALES_CHANNEL','EXTERNAL_APPROVED_LINES','APPROVED_LINES','ACNT_BILL_LNAME_MATCHES','ACNT_SHIP_FNAME_MATCHES','ACNT_SHIP_LNAME_MATCHES','SHIP_BILL_FNAME_MATCHES','BILL_SHIP_ADDR_MATCHES','MAKE1','MAKE2','MAKE3','MAKE4','MAKE5','MODEL1','MODEL2','MODEL3','MODEL4','MODEL5','PRICE1','PRICE2','PRICE3','PRICE4','PRICE5','HOUR_OF_DAY','FINAL_RESULT']]

#data=data_df[['TOTAL_PRICE','THIRD_PARTY_ID_SCORE','IS_EXISTING_CUSTOMER','NUM_PORTIN','FIRST_PARTY_ID_SCORE','ONETIMECHARGE','INSTALLMENT_AMOUNT','DEVICE_AT_HOME','FRAUDNET_SCORE','NUM_BYOD','IDA_RESULT','MONTHLYRECURRINGCHARGE','EXTERNAL_CREDIT_CHECK_DONE','SALES_CHANNEL','ACNT_BILL_LNAME_MATCHES','ACNT_SHIP_FNAME_MATCHES','ACNT_SHIP_LNAME_MATCHES','SHIP_BILL_FNAME_MATCHES','BILL_SHIP_ADDR_MATCHES','MODEL1','MODEL2','MODEL3','MODEL4','MODEL5','ACTIVE_WATCH_RESULT']]
#test_data=test_df[['TOTAL_PRICE','THIRD_PARTY_ID_SCORE','IS_EXISTING_CUSTOMER','NUM_PORTIN','FIRST_PARTY_ID_SCORE','ONETIMECHARGE','INSTALLMENT_AMOUNT','DEVICE_AT_HOME','FRAUDNET_SCORE','NUM_BYOD','IDA_RESULT','MONTHLYRECURRINGCHARGE','EXTERNAL_CREDIT_CHECK_DONE','SALES_CHANNEL','ACNT_BILL_LNAME_MATCHES','ACNT_SHIP_FNAME_MATCHES','ACNT_SHIP_LNAME_MATCHES','SHIP_BILL_FNAME_MATCHES','BILL_SHIP_ADDR_MATCHES','MODEL1','MODEL2','MODEL3','MODEL4','MODEL5','ACTIVE_WATCH_RESULT']]

#data=data_df[['TOTAL_PRICE','THIRD_PARTY_ID_SCORE','IS_EXISTING_CUSTOMER','NUM_PORTIN','FIRST_PARTY_ID_SCORE','ONETIMECHARGE','INSTALLMENT_AMOUNT','DEVICE_AT_HOME','FRAUDNET_SCORE','NUM_BYOD','IDA_RESULT','EXTERNAL_CREDIT_CHECK_DONE','SALES_CHANNEL','MODEL1','MODEL2','MODEL3','MODEL4','MODEL5','ACTIVE_WATCH_RESULT']]
#test_data=test_df[['TOTAL_PRICE','THIRD_PARTY_ID_SCORE','IS_EXISTING_CUSTOMER','NUM_PORTIN','FIRST_PARTY_ID_SCORE','ONETIMECHARGE','INSTALLMENT_AMOUNT','DEVICE_AT_HOME','FRAUDNET_SCORE','NUM_BYOD','IDA_RESULT','EXTERNAL_CREDIT_CHECK_DONE','SALES_CHANNEL','MODEL1','MODEL2','MODEL3','MODEL4','MODEL5','ACTIVE_WATCH_RESULT']]

# data=data_df[['TOTAL_PRICE','THIRD_PARTY_ID_SCORE','IS_EXISTING_CUSTOMER','NUM_PORTIN','FIRST_PARTY_ID_SCORE','ONETIMECHARGE','INSTALLMENT_AMOUNT','DEVICE_AT_HOME','FRAUDNET_SCORE','NUM_BYOD','IDA_RESULT','EXTERNAL_CREDIT_CHECK_DONE','SALES_CHANNEL','MODEL1','MODEL2','MODEL3','MODEL4','MODEL5','ACTIVE_WATCH_RESULT']]
# test_data=test_df[['TOTAL_PRICE','THIRD_PARTY_ID_SCORE','IS_EXISTING_CUSTOMER','NUM_PORTIN','FIRST_PARTY_ID_SCORE','ONETIMECHARGE','INSTALLMENT_AMOUNT','DEVICE_AT_HOME','FRAUDNET_SCORE','NUM_BYOD','IDA_RESULT','EXTERNAL_CREDIT_CHECK_DONE','SALES_CHANNEL','MODEL1','MODEL2','MODEL3','MODEL4','MODEL5','ACTIVE_WATCH_RESULT']]

# %%
data.shape
# Out:
# (133797, 39)

# %%
test_data.shape
# Out:
# (26321, 39)

# %%
data.head()
# Out:
#    TOTAL_PRICE  THIRD_PARTY_ID_SCORE IS_EXISTING_CUSTOMER  NUM_PORTIN  \
# 0 847.92        504                   N                    0
# 1 129.96        384                   Y                    0
# 2 1099.84       540                   N                    0
# 3 834.36        410                   Y                    1
# 4 0.00          348                   N                    0
#
#    FIRST_PARTY_ID_SCORE  ONETIMECHARGE  INSTALLMENT_AMOUNT DEVICE_AT_HOME  \
# 0  466                  33.33          33.33                Y
# 1  293                  4.99           4.99                 N
# 2  494                  41.66          41.66                N
# 3  331                  32.49          32.49                N
# 4  409                  0.00           0.00                 Y
#
#    FRAUDNET_SCORE  NUM_BYOD      ...      MODEL3  MODEL4  MODEL5 PRICE1  \
# 0 200.00           0             ...       NaN    NaN     NaN    649.99
# 1 nan              0             ...       NaN    NaN     NaN    119.99
# 2 nan              0             ...       NaN    NaN     NaN    999.99
# 3 nan              0             ...       NaN    NaN     NaN    779.99
# 4 200.00           1             ...       NaN    NaN     NaN    0.00
#
#   PRICE2  PRICE3  PRICE4  PRICE5  HOUR_OF_DAY  FINAL_RESULT
# 0  NaN   nan     nan     nan      0            GREEN
# 1  NaN   nan     nan     nan      0            GREEN
# 2  NaN   nan     nan     nan      0            GREEN
# 3  NaN   nan     nan     nan      0            GREEN
# 4  NaN   nan     nan     nan      0            GREEN
#
# [5 rows x 39 columns]

# %%
data['MODEL2'].fillna('NA',inplace=True)
data['MODEL3'].fillna('NA',inplace=True)
data['MODEL4'].fillna('NA',inplace=True)
data['MODEL5'].fillna('NA',inplace=True)


test_data['MODEL2'].fillna('NA',inplace=True)
test_data['MODEL3'].fillna('NA',inplace=True)
test_data['MODEL4'].fillna('NA',inplace=True)
test_data['MODEL5'].fillna('NA',inplace=True)

# %%
data.head()
# Out:
#    TOTAL_PRICE  THIRD_PARTY_ID_SCORE IS_EXISTING_CUSTOMER  NUM_PORTIN  \
# 0 847.92        504                   N                    0
# 1 129.96        384                   Y                    0
# 2 1099.84       540                   N                    0
# 3 834.36        410                   Y                    1
# 4 0.00          348                   N                    0
#
#    FIRST_PARTY_ID_SCORE  ONETIMECHARGE  INSTALLMENT_AMOUNT DEVICE_AT_HOME  \
# 0  466                  33.33          33.33                Y
# 1  293                  4.99           4.99                 N
# 2  494                  41.66          41.66                N
# 3  331                  32.49          32.49                N
# 4  409                  0.00           0.00                 Y
#
#    FRAUDNET_SCORE  NUM_BYOD      ...      MODEL3  MODEL4  MODEL5 PRICE1  \
# 0 200.00           0             ...       NA     NA      NA     649.99
# 1 nan              0             ...       NA     NA      NA     119.99
# 2 nan              0             ...       NA     NA      NA     999.99
# 3 nan              0             ...       NA     NA      NA     779.99
# 4 200.00           1             ...       NA     NA      NA     0.00
#
#   PRICE2  PRICE3  PRICE4  PRICE5  HOUR_OF_DAY  FINAL_RESULT
# 0  NaN   nan     nan     nan      0            GREEN
# 1  NaN   nan     nan     nan      0            GREEN
# 2  NaN   nan     nan     nan      0            GREEN
# 3  NaN   nan     nan     nan      0            GREEN
# 4  NaN   nan     nan     nan      0            GREEN
#
# [5 rows x 39 columns]

# %%
def label_color(row):
    color = row['FINAL_RESULT']
#     print(color)
    if color == 'GREEN':
        return 0
    elif color == 'YELLOW':
        return 1
    elif color == 'RED':
        return 2
    else:
        print('We Received UnExpected Color:',color)
        raise ValueError('invalid result:', color)

# %%
data['label'] = data.apply(label_color, axis=1)
data.drop(columns=['FINAL_RESULT'], inplace=True)

test_data['label'] = test_data.apply(label_color, axis=1)
test_data.drop(columns=['FINAL_RESULT'], inplace=True)

# %%
data.head()
# Out:
#    TOTAL_PRICE  THIRD_PARTY_ID_SCORE IS_EXISTING_CUSTOMER  NUM_PORTIN  \
# 0 847.92        504                   N                    0
# 1 129.96        384                   Y                    0
# 2 1099.84       540                   N                    0
# 3 834.36        410                   Y                    1
# 4 0.00          348                   N                    0
#
#    FIRST_PARTY_ID_SCORE  ONETIMECHARGE  INSTALLMENT_AMOUNT DEVICE_AT_HOME  \
# 0  466                  33.33          33.33                Y
# 1  293                  4.99           4.99                 N
# 2  494                  41.66          41.66                N
# 3  331                  32.49          32.49                N
# 4  409                  0.00           0.00                 Y
#
#    FRAUDNET_SCORE  NUM_BYOD  ...   MODEL3  MODEL4  MODEL5 PRICE1 PRICE2  \
# 0 200.00           0         ...    NA     NA      NA     649.99  NaN
# 1 nan              0         ...    NA     NA      NA     119.99  NaN
# 2 nan              0         ...    NA     NA      NA     999.99  NaN
# 3 nan              0         ...    NA     NA      NA     779.99  NaN
# 4 200.00           1         ...    NA     NA      NA     0.00    NaN
#
#    PRICE3  PRICE4  PRICE5  HOUR_OF_DAY  label
# 0 nan     nan     nan      0            0
# 1 nan     nan     nan      0            0
# 2 nan     nan     nan      0            0
# 3 nan     nan     nan      0            0
# 4 nan     nan     nan      0            0
#
# [5 rows x 39 columns]

# %%
test_data.head()
# Out:
#    TOTAL_PRICE  THIRD_PARTY_ID_SCORE IS_EXISTING_CUSTOMER  NUM_PORTIN  \
# 0 1249.99       451                   Y                    1
# 1 1337.42       306                   Y                    0
# 2 900.84        515                   Y                    1
# 3 1059.99       547                   Y                    0
# 4 399.84        425                   Y                    0
#
#    FIRST_PARTY_ID_SCORE  ONETIMECHARGE  INSTALLMENT_AMOUNT DEVICE_AT_HOME  \
# 0  393                  1249.99        0.00                 N
# 1  441                  52.08          52.08                N
# 2  473                  35.41          35.41                N
# 3  302                  999.99         0.00                 N
# 4  396                  16.66          16.66                N
#
#    FRAUDNET_SCORE  NUM_BYOD  ...   MODEL3  MODEL4  MODEL5  PRICE1 PRICE2  \
# 0 nan              0         ...    NA     NA      NA     1249.99 nan
# 1 nan              0         ...    NA     NA      NA     1249.99 nan
# 2 nan              0         ...    NA     NA      NA     849.99  nan
# 3 nan              0         ...    NA     NA      NA     999.99  nan
# 4 nan              0         ...    NA     NA      NA     399.99  nan
#
#    PRICE3  PRICE4  PRICE5  HOUR_OF_DAY  label
# 0 nan     nan     nan      16           0
# 1 nan     nan     nan      16           0
# 2 nan     nan     nan      16           0
# 3 nan     nan     nan      16           0
# 4 nan     nan     nan      16           0
#
# [5 rows x 39 columns]

# %%
data.shape
# Out:
# (133797, 39)

# %%
test_data.shape
# Out:
# (26321, 39)

# %%
collections.Counter(data['label'])
# Out:
# Counter({0: 110297, 1: 12324, 2: 11176})

# %%
green_df = data[data['label'] == 0]
yellow_df = data[data['label'] == 1]
red_df = data[data['label'] == 2]

# %%
green_under_df = green_df.sample(11176)
yellow_over_df= yellow_df.sample(11176, replace=True)

# %%
balanced_data_df = pd.concat([green_under_df, yellow_over_df, red_df])

# %%
balanced_data_df.shape
# Out:
# (33528, 39)

# %%
X_train = balanced_data_df.drop(columns=['label'])
Y_train = balanced_data_df['label']

X_test = test_data.drop(columns=['label'])
Y_test = test_data['label']

# %%
X_train.shape
# Out:
# (33528, 38)

# %%
Y_train = np.array(Y_train)

# %%
Y_train.shape
# Out:
# (33528,)

# %%
X_test.shape
# Out:
# (26321, 38)

# %%
Y_test.shape
# Out:
# (26321,)

# %%
balanced_data_df.to_csv('data/risk_train.csv',index=False)
test_data.to_csv('data/risk_test.csv',index=False)

# %%
ws = Workspace.from_config()

# choose a name for experiment
experiment_name = 'risk-remote'
# project folder
project_folder = './ml_experiment/risk-remote'
 
experiment = Experiment(ws, experiment_name)
 
output = {}
output['SDK version'] = azureml.core.VERSION
output['Subscription ID'] = ws.subscription_id
output['Workspace Name'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
output['Project Directory'] = project_folder
output['Experiment Name'] = experiment.name
pd.set_option('display.max_colwidth', -1)
outputDf = pd.DataFrame(data = output, index = [''])
outputDf.T
# Out:
#
# SDK version        1.0.65
# Subscription ID    be564fde-136b-4709-b7b6-abfc0bdfc134
# Workspace Name     xm-ml-workspace
# Resource Group     xm-ml
# Location           centralus
# Project Directory  ./ml_experiment/risk-remote
# Experiment Name    risk-remote

# %%
train_dflow = dprep.read_csv('data/risk_train.csv', infer_column_types=True)
train_dflow.get_profile()
# Out:
# ColumnProfile:
#     column_name: TOTAL_PRICE
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 7838.2
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: >1000
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 395.97722166792073
#           50%: 868.380227361767
#           75%: 1244.0914424355856
#           95%: 2389.89819337474
#           99%: 3701.4900051337463
#         99.9%: 6222.251772800033
#
#     mean: 953.1549949296073
#     std: 767.2909293025073
#     variance: 588735.3701899052
#     skewness: 1.89436489418495
#     kurtosis: 7.919741308588572
#     whisker_top: 2504.0989999999997
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: THIRD_PARTY_ID_SCORE
#     type: FieldType.INTEGER
#
#     min: 230.0
#     max: 999.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 713
#
#
#     Quantiles (est.):
#          0.1%: 255.52836090225563
#            1%: 341.81132721684173
#            5%: 341.2542372881355
#           25%: 387.5632870352153
#           50%: 460.01920352002367
#           75%: 585.3788624342103
#           95%: 786.0996702763454
#           99%: 997.0725234633178
#         99.9%: 999.0
#
#     mean: 499.2093474111199
#     std: 149.76912582940795
#     variance: 22430.791051705037
#     skewness: 1.0220683612054682
#     kurtosis: 0.6918970353912446
#     whisker_top: 881.5714285714284
#     whisker_bottom: 230.0
#
# ColumnProfile:
#     column_name: IS_EXISTING_CUSTOMER
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
# ColumnProfile:
#     column_name: NUM_PORTIN
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 5.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 6
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 3.0
#           99%: 4.0
#         99.9%: 5.0
#
#     mean: 0.7474946313528974
#     std: 0.978186787636369
#     variance: 0.956849391506359
#     skewness: 1.568605569602742
#     kurtosis: 2.4602118997270184
#     whisker_top: 2.0
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: FIRST_PARTY_ID_SCORE
#     type: FieldType.INTEGER
#
#     min: 100.0
#     max: 999.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 632
#
#
#     Quantiles (est.):
#          0.1%: 163.72764145658263
#            1%: 286.877247920509
#            5%: 284.6748466257668
#           25%: 336.3031829631326
#           50%: 407.86965402947277
#           75%: 510.6593217543386
#           95%: 654.2824648125502
#           99%: 993.558339722406
#         99.9%: 999.0
#
#     mean: 432.2497017418283
#     std: 132.3968224237831
#     variance: 17528.91858791476
#     skewness: 1.101881119422308
#     kurtosis: 2.3252768866538727
#     whisker_top: 753.1126760563379
#     whisker_bottom: 100.0
#
# ColumnProfile:
#     column_name: ONETIMECHARGE
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 3749.97
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: >1000
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 19.18026460146261
#           50%: 41.65999924567014
#           75%: 52.08
#           95%: 601.2431825516754
#           99%: 1250.0158810085618
#         99.9%: 2493.5362386898664
#
#     mean: 97.50955589358166
#     std: 246.10094798294747
#     variance: 60565.67659810542
#     skewness: 5.348716148488814
#     kurtosis: 37.275326109923256
#     whisker_top: 96.67672862453527
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: INSTALLMENT_AMOUNT
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 302.05
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 495
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 10.14544888888889
#           50%: 32.24857573595062
#           75%: 47.9099979757085
#           95%: 92.43923550527899
#           99%: 143.9074802959717
#         99.9%: 245.40046451620475
#
#     mean: 35.435601884991364
#     std: 30.991403531883027
#     variance: 960.4670928760116
#     skewness: 1.7946996176223664
#     kurtosis: 7.169210646944586
#     whisker_top: 104.36805755395683
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: DEVICE_AT_HOME
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
# ColumnProfile:
#     column_name: FRAUDNET_SCORE
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 8250.0
#     count: 33528.0
#     missing_count: 21284.0
#     not_missing_count: 12244.0
#     percent_missing: 0.634812693867812
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 105
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 200.0
#            5%: 200.0
#           25%: 200.0
#           50%: 200.0
#           75%: 350.0
#           95%: 1700.0
#           99%: 3748.6665579710075
#         99.9%: 6620.133333333323
#
#     mean: 412.57758902319455
#     std: 701.8136620071551
#     variance: 492542.4161798933
#     skewness: 5.330720401867069
#     kurtosis: 34.027122639674126
#     whisker_top: 507.4257425742574
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: NUM_BYOD
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 5.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 6
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 1.0
#           99%: 2.0
#         99.9%: 3.986887931034493
#
#     mean: 0.20230851825340085
#     std: 0.5370720307675703
#     variance: 0.2884463662328019
#     skewness: 3.1605381579411462
#     kurtosis: 11.688845786645794
#     whisker_top: 0.0
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: IDA_RESULT
#     type: FieldType.STRING
#
#     min:
#     max: YELLOW
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 131.0
#     unique_values: 4
#
#
# ColumnProfile:
#     column_name: ALLOWED_LINES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 5.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 6
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 2.0
#            5%: 2.0
#           25%: 3.0
#           50%: 4.0
#           75%: 5.0
#           95%: 5.0
#           99%: 5.0
#         99.9%: 5.0
#
#     mean: 3.923854688618456
#     std: 1.3108980944155302
#     variance: 1.718453813942268
#     skewness: -1.0748562748290833
#     kurtosis: 0.29014742547585826
#     whisker_top: 5.0
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: MONTHLYRECURRINGCHARGE
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 539.15
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: >1000
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 9.9900604767205
#            5%: 9.989954128440367
#           25%: 30.797376027594048
#           50%: 62.299746944381596
#           75%: 97.0799069478908
#           95%: 167.4628693520012
#           99%: 256.230187519633
#         99.9%: 393.3158700830915
#
#     mean: 69.11496212121183
#     std: 52.92004550795782
#     variance: 2800.531216564327
#     skewness: 1.626765454985009
#     kurtosis: 5.798754216708113
#     whisker_top: 195.52160583941605
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: EXTERNAL_CREDIT_CHECK_DONE
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
# ColumnProfile:
#     column_name: SALES_CHANNEL
#     type: FieldType.STRING
#
#     min: ONLINE
#     max: TELESALES
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 3
#
#
# ColumnProfile:
#     column_name: EXTERNAL_APPROVED_LINES
#     type: FieldType.INTEGER
#
#     min: -1.0
#     max: 5.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 7
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 2.0
#           75%: 4.0
#           95%: 5.0
#           99%: 5.0
#         99.9%: 5.0
#
#     mean: 1.9743796230016821
#     std: 1.9341085427571638
#     variance: 3.74077585516624
#     skewness: 0.36014603092918623
#     kurtosis: -1.425652062952287
#     whisker_top: 5.0
#     whisker_bottom: -1.0
#
# ColumnProfile:
#     column_name: APPROVED_LINES
#     type: FieldType.INTEGER
#
#     min: -3.0
#     max: 5.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 9
#
#
#     Quantiles (est.):
#          0.1%: -1.0899132369299223
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 4.999583630739948
#           95%: 5.0
#           99%: 5.0
#         99.9%: 5.0
#
#     mean: 1.5219816272965803
#     std: 2.2370601691230507
#     variance: 5.004438200276852
#     skewness: 0.8224095086711894
#     kurtosis: -1.2622659574181132
#     whisker_top: 5.0
#     whisker_bottom: -3.0
#
# ColumnProfile:
#     column_name: ACNT_BILL_LNAME_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9319673109043136
#     std: 0.25180574546629897
#     variance: 0.06340613344983853
#     skewness: -3.4308544177683995
#     kurtosis: 9.771053468244435
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: ACNT_SHIP_FNAME_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9437485087091355
#     std: 0.2304101656537457
#     variance: 0.05308884443658653
#     skewness: -3.851698750254417
#     kurtosis: 12.8359661085592
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: ACNT_SHIP_LNAME_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9591386303984736
#     std: 0.19797193496983367
#     variance: 0.03919288703570005
#     skewness: -4.638283060511173
#     kurtosis: 19.5142517806005
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: SHIP_BILL_FNAME_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9377833452636604
#     std: 0.24155223631984651
#     variance: 0.05834748287111898
#     skewness: -3.6246428075950448
#     kurtosis: 11.13836769623852
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: BILL_SHIP_ADDR_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.8543008828441868
#     std: 0.352809576078096
#     variance: 0.1244745969724058
#     skewness: -2.0083939867459484
#     kurtosis: 2.0337070656411385
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: MAKE1
#     type: FieldType.STRING
#
#     min: Apple
#     max: Zagg
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 15
#
#
# ColumnProfile:
#     column_name: MAKE2
#     type: FieldType.STRING
#
#     min:
#     max: Zagg
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 25690.0
#     unique_values: 16
#
#
# ColumnProfile:
#     column_name: MAKE3
#     type: FieldType.STRING
#
#     min:
#     max: Zagg
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 29875.0
#     unique_values: 16
#
#
# ColumnProfile:
#     column_name: MAKE4
#     type: FieldType.STRING
#
#     min:
#     max: Zagg
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 32217.0
#     unique_values: 15
#
#
# ColumnProfile:
#     column_name: MAKE5
#     type: FieldType.STRING
#
#     min:
#     max: Zagg
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 33215.0
#     unique_values: 12
#
#
# ColumnProfile:
#     column_name: MODEL1
#     type: FieldType.STRING
#
#     min: 3' Lightning ChargeSync Cable
#     max: power boost mini
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 137
#
#
# ColumnProfile:
#     column_name: MODEL2
#     type: FieldType.STRING
#
#     min: 3' Type C ChargeSync
#     max: power boost mini
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 147
#
#
# ColumnProfile:
#     column_name: MODEL3
#     type: FieldType.STRING
#
#     min: 3' Lightning ChargeSync Cable
#     max: power boost mini
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 127
#
#
# ColumnProfile:
#     column_name: MODEL4
#     type: FieldType.STRING
#
#     min: 3' Lightning ChargeSync Cable
#     max: power boost mini
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 91
#
#
# ColumnProfile:
#     column_name: MODEL5
#     type: FieldType.STRING
#
#     min: 64GB MicroSDXC Memory Card
#     max: power boost mini
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 62
#
#
# ColumnProfile:
#     column_name: PRICE1
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1449.99
#     count: 33528.0
#     missing_count: 2.0
#     not_missing_count: 33526.0
#     percent_missing: 5.965163445478406e-05
#     error_count: 5.0
#     empty_count: 0.0
#     unique_values: 49
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 174.12954785954796
#            5%: 157.64999999999995
#           25%: 449.99
#           50%: 699.99
#           75%: 1078.5662683256176
#           95%: 1249.99
#           99%: 1449.99
#         99.9%: 1449.99
#
#     mean: 729.1458354464401
#     std: 377.5342726598134
#     variance: 142532.1270327743
#     skewness: -0.1320727974489247
#     kurtosis: -0.9722045238144408
#     whisker_top: 1449.99
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: PRICE2
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1449.99
#     count: 33528.0
#     missing_count: 25691.0
#     not_missing_count: 7837.0
#     percent_missing: 0.7662550703889287
#     error_count: 1.0
#     empty_count: 0.0
#     unique_values: 47
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 43.389209885789185
#            5%: 43.11666666666667
#           25%: 349.99
#           50%: 599.99
#           75%: 947.6575094816689
#           95%: 1249.99
#           99%: 1449.99
#         99.9%: 1449.99
#
#     mean: 600.5762595712097
#     std: 385.5985296634373
#     variance: 148686.22607860476
#     skewness: 0.1977358306270102
#     kurtosis: -0.9268387927043493
#     whisker_top: 1449.99
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: PRICE3
#     type: FieldType.STRING
#
#     min:
#     max: 999.99
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 29875.0
#     unique_values: 47
#
#
# ColumnProfile:
#     column_name: PRICE4
#     type: FieldType.STRING
#
#     min:
#     max: 999.99
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 32217.0
#     unique_values: 43
#
#
# ColumnProfile:
#     column_name: PRICE5
#     type: FieldType.STRING
#
#     min:
#     max: 999.99
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 33215.0
#     unique_values: 37
#
#
# ColumnProfile:
#     column_name: HOUR_OF_DAY
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 23.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 24
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.9885033339740086
#            5%: 1.96234309623431
#           25%: 13.0
#           50%: 17.0
#           75%: 20.0
#           95%: 23.0
#           99%: 23.0
#         99.9%: 23.0
#
#     mean: 15.022011453113823
#     std: 6.860049014642683
#     variance: 47.06027248330004
#     skewness: -1.0580926273348878
#     kurtosis: -0.04522729769837719
#     whisker_top: 23.0
#     whisker_bottom: 2.9761904761904745
#
# ColumnProfile:
#     column_name: label
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 2.0
#     count: 33528.0
#     missing_count: 0.0
#     not_missing_count: 33528.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 3
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 2.0
#           95%: 2.0
#           99%: 2.0
#         99.9%: 2.0
#
#     mean: 1.0000000000000036
#     std: 0.8165087575390032
#     variance: 0.6666865511378868
#     skewness: -3.635645228177323e-15
#     kurtosis: -1.500089476117299
#     whisker_top: 2.0
#     whisker_bottom: 0.0

# %%
test_dflow = dprep.read_csv('data/risk_test.csv', infer_column_types=True)
test_dflow.get_profile()
# Out:
# ColumnProfile:
#     column_name: TOTAL_PRICE
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 7734.95
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: >1000
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 185.428535476424
#           50%: 743.3517886766093
#           75%: 1092.0849908422715
#           95%: 1500.8365112842575
#           99%: 2683.9094371323536
#         99.9%: 4555.261020582423
#
#     mean: 715.190563808367
#     std: 587.8550807485705
#     variance: 345573.5959619082
#     skewness: 1.5953333777032828
#     kurtosis: 8.588281414875029
#     whisker_top: 2385.9677027027024
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: THIRD_PARTY_ID_SCORE
#     type: FieldType.INTEGER
#
#     min: 233.0
#     max: 999.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 662
#
#
#     Quantiles (est.):
#          0.1%: 249.73675692307694
#            1%: 337.0686233055591
#            5%: 336.1627906976745
#           25%: 376.3217836952223
#           50%: 433.65834095159784
#           75%: 514.1081380711241
#           95%: 686.3556631641551
#           99%: 850.1604650509312
#         99.9%: 999.0
#
#     mean: 458.31681926978314
#     std: 117.11300803331825
#     variance: 13715.456650612066
#     skewness: 1.3351951728113052
#     kurtosis: 2.60321676035867
#     whisker_top: 718.381443298969
#     whisker_bottom: 233.0
#
# ColumnProfile:
#     column_name: IS_EXISTING_CUSTOMER
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
# ColumnProfile:
#     column_name: NUM_PORTIN
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 5.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 6
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 1.0
#           95%: 2.0
#           99%: 3.0
#         99.9%: 4.740562162162167
#
#     mean: 0.7994757038106444
#     std: 0.7163853235445258
#     variance: 0.5132079317899949
#     skewness: 1.0732679273133572
#     kurtosis: 2.9059920221819917
#     whisker_top: 2.0
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: FIRST_PARTY_ID_SCORE
#     type: FieldType.INTEGER
#
#     min: 88.0
#     max: 999.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 612
#
#
#     Quantiles (est.):
#          0.1%: 154.72228260869565
#            1%: 270.74636184592543
#            5%: 269.64814814814827
#           25%: 315.86395585024513
#           50%: 376.60977698133735
#           75%: 452.6637836357945
#           95%: 589.8524321908816
#           99%: 690.3401480263161
#         99.9%: 999.0
#
#     mean: 392.43353216063343
#     std: 109.85195515020884
#     variance: 12067.452050323493
#     skewness: 1.140462075019459
#     kurtosis: 3.214746321385011
#     whisker_top: 653.6486486486485
#     whisker_bottom: 128.83333333333334
#
# ColumnProfile:
#     column_name: ONETIMECHARGE
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 3249.96
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 495
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 10.69308122040692
#           50%: 29.16
#           75%: 45.83
#           95%: 699.99
#           99%: 1163.6361627235542
#         99.9%: 1909.6506692768307
#
#     mean: 90.38147182857816
#     std: 229.48445623645262
#     variance: 52663.11565414033
#     skewness: 4.325333640908036
#     kurtosis: 23.633292015411563
#     whisker_top: 92.6940909090909
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: INSTALLMENT_AMOUNT
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 302.05
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 248
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 27.135941231727504
#           75%: 41.660204928835
#           95%: 58.18869411330144
#           99%: 104.41623886752137
#         99.9%: 183.52820021428585
#
#     mean: 25.67347175259305
#     std: 24.017436319977364
#     variance: 576.8372473841678
#     skewness: 1.6471008780673273
#     kurtosis: 8.375039602501259
#     whisker_top: 97.27136363636362
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: DEVICE_AT_HOME
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
# ColumnProfile:
#     column_name: FRAUDNET_SCORE
#     type: FieldType.DECIMAL
#
#     min: 200.0
#     max: 6550.0
#     count: 26321.0
#     missing_count: 26244.0
#     not_missing_count: 77.0
#     percent_missing: 0.9970745792333118
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 12
#
#
#     Quantiles (est.):
#          0.1%: 200.0
#            1%: 200.0
#            5%: 200.0
#           25%: 200.0
#           50%: 200.0
#           75%: 350.0
#           95%: 829.9999999999982
#           99%: 5389.000000000017
#         99.9%: 6550.0
#
#     mean: 395.45454545454555
#     std: 784.6882476072996
#     variance: 615735.6459330146
#     skewness: 6.564400513188826
#     kurtosis: 46.84762226076498
#     whisker_top: 450.0
#     whisker_bottom: 200.0
#
# ColumnProfile:
#     column_name: NUM_BYOD
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 5.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 6
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 1.0
#           99%: 2.0
#         99.9%: 4.0
#
#     mean: 0.2641237035067063
#     std: 0.5642534141641957
#     variance: 0.3183819153959514
#     skewness: 2.4758497887911006
#     kurtosis: 7.468904550437152
#     whisker_top: 0.0
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: IDA_RESULT
#     type: FieldType.STRING
#
#     min:
#     max: YELLOW
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 44.0
#     unique_values: 4
#
#
# ColumnProfile:
#     column_name: ALLOWED_LINES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 5.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 6
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 2.0
#            5%: 2.0
#           25%: 3.0
#           50%: 5.0
#           75%: 5.0
#           95%: 5.0
#           99%: 5.0
#         99.9%: 5.0
#
#     mean: 4.080430074845163
#     std: 1.2215256780771562
#     variance: 1.492124982201856
#     skewness: -1.2840333678560134
#     kurtosis: 0.8806801549949541
#     whisker_top: 5.0
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: MONTHLYRECURRINGCHARGE
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 485.4
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: >1000
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 12.0
#            5%: 12.0
#           25%: 29.275530555555555
#           50%: 54.66641029156369
#           75%: 86.6523259518912
#           95%: 116.30279466097792
#           99%: 194.2528151095734
#         99.9%: 307.6988505469757
#
#     mean: 59.09666881957345
#     std: 40.60179615887481
#     variance: 1648.5058513268216
#     skewness: 1.3099613794843565
#     kurtosis: 4.831960813996513
#     whisker_top: 167.30842857142858
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: EXTERNAL_CREDIT_CHECK_DONE
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
# ColumnProfile:
#     column_name: SALES_CHANNEL
#     type: FieldType.STRING
#
#     min: ONLINE
#     max: TELESALES
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 3
#
#
# ColumnProfile:
#     column_name: EXTERNAL_APPROVED_LINES
#     type: FieldType.INTEGER
#
#     min: -1.0
#     max: 5.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 7
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 3.795353982300887
#           95%: 5.0
#           99%: 5.0
#         99.9%: 5.0
#
#     mean: 1.7119030431974456
#     std: 1.9247069880870527
#     variance: 3.704496989991134
#     skewness: 0.5773668606836332
#     kurtosis: -1.2510043905885289
#     whisker_top: 5.0
#     whisker_bottom: -1.0
#
# ColumnProfile:
#     column_name: APPROVED_LINES
#     type: FieldType.INTEGER
#
#     min: -5.0
#     max: 5.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 9
#
#
#     Quantiles (est.):
#          0.1%: -1.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 5.0
#           95%: 5.0
#           99%: 5.0
#         99.9%: 5.0
#
#     mean: 1.8203715664298454
#     std: 2.331516562667732
#     variance: 5.435969481993958
#     skewness: 0.5327540440253352
#     kurtosis: -1.6569220342471844
#     whisker_top: 5.0
#     whisker_bottom: -5.0
#
# ColumnProfile:
#     column_name: ACNT_BILL_LNAME_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9512556513810306
#     std: 0.21533717470892186
#     variance: 0.04637009881162074
#     skewness: -4.190994961002937
#     kurtosis: 15.565030121538598
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: ACNT_SHIP_FNAME_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9653888530071083
#     std: 0.18279629371461661
#     variance: 0.03341448499580038
#     skewness: -5.091691546636348
#     kurtosis: 23.926231827242486
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: ACNT_SHIP_LNAME_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9770145511188747
#     std: 0.14985983869877306
#     variance: 0.02245797125482228
#     skewness: -6.365900728254075
#     kurtosis: 38.52615579042314
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: SHIP_BILL_FNAME_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.9442270430454806
#     std: 0.22948711309273293
#     variance: 0.052664335075636795
#     skewness: -3.871329938949919
#     kurtosis: 12.987688935019872
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: BILL_SHIP_ADDR_MATCHES
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.8914934842901105
#     std: 0.31102496205082003
#     variance: 0.09673652701871403
#     skewness: -2.5173452825227405
#     kurtosis: 4.337192056441258
#     whisker_top: 1.0
#     whisker_bottom: 1.0
#
# ColumnProfile:
#     column_name: MAKE1
#     type: FieldType.STRING
#
#     min: Apple
#     max: Zagg
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 13
#
#
# ColumnProfile:
#     column_name: MAKE2
#     type: FieldType.STRING
#
#     min:
#     max: Zagg
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 22539.0
#     unique_values: 14
#
#
# ColumnProfile:
#     column_name: MAKE3
#     type: FieldType.STRING
#
#     min:
#     max: Zagg
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 25581.0
#     unique_values: 11
#
#
# ColumnProfile:
#     column_name: MAKE4
#     type: FieldType.STRING
#
#     min:
#     max: Zagg
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 26074.0
#     unique_values: 10
#
#
# ColumnProfile:
#     column_name: MAKE5
#     type: FieldType.STRING
#
#     min:
#     max: Zagg
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 26261.0
#     unique_values: 8
#
#
# ColumnProfile:
#     column_name: MODEL1
#     type: FieldType.STRING
#
#     min: 3' Micro ChargeSync Cable
#     max: power boost mini
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 111
#
#
# ColumnProfile:
#     column_name: MODEL2
#     type: FieldType.STRING
#
#     min: 3' Lightning ChargeSync Cable
#     max: power boost XL
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 92
#
#
# ColumnProfile:
#     column_name: MODEL3
#     type: FieldType.STRING
#
#     min: 3' Micro ChargeSync Cable
#     max: power boost mini
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 70
#
#
# ColumnProfile:
#     column_name: MODEL4
#     type: FieldType.STRING
#
#     min: Apple iPhone 11 InvisibleShield glass visionguard+
#     max: power boost XXL
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 47
#
#
# ColumnProfile:
#     column_name: MODEL5
#     type: FieldType.STRING
#
#     min: 6' Type C ChargeSync Cable
#     max: moto e⁶
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 22
#
#
# ColumnProfile:
#     column_name: PRICE1
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1449.99
#     count: 26321.0
#     missing_count: 8.0
#     not_missing_count: 26313.0
#     percent_missing: 0.0003039398199156567
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 47
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 144.16295637812107
#            5%: 143.99
#           25%: 449.99
#           50%: 699.99
#           75%: 999.99
#           95%: 1249.99
#           99%: 1439.199544573642
#         99.9%: 1449.99
#
#     mean: 688.8260312393128
#     std: 352.6688869219314
#     variance: 124375.34380275404
#     skewness: -0.042592952224671306
#     kurtosis: -0.6212266106067368
#     whisker_top: 1449.99
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: PRICE2
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1449.99
#     count: 26321.0
#     missing_count: 22539.0
#     not_missing_count: 3782.0
#     percent_missing: 0.8563124501348733
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 46
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 299.99
#           50%: 554.8750574712644
#           75%: 759.9812242211497
#           95%: 1249.99
#           99%: 1409.863015873015
#         99.9%: 1449.99
#
#     mean: 565.2754151242722
#     std: 388.2369649910048
#     variance: 150727.94098542669
#     skewness: 0.24216108016506788
#     kurtosis: -0.7642091031484992
#     whisker_top: 1405.5455555555557
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: PRICE3
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1449.99
#     count: 26321.0
#     missing_count: 25581.0
#     not_missing_count: 740.0
#     percent_missing: 0.9718855666578018
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 40
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 208.75320000000002
#           50%: 599.99
#           75%: 749.99
#           95%: 1249.99
#           99%: 1449.99
#         99.9%: 1449.99
#
#     mean: 559.2917972972974
#     std: 401.6541951483345
#     variance: 161326.0924802564
#     skewness: 0.20744092924097463
#     kurtosis: -0.8610400789984065
#     whisker_top: 1449.99
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: PRICE4
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1449.99
#     count: 26321.0
#     missing_count: 26074.0
#     not_missing_count: 247.0
#     percent_missing: 0.9906158580601041
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 34
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 49.95
#           50%: 549.99
#           75%: 878.115
#           95%: 1249.99
#           99%: 1449.99
#         99.9%: 1449.99
#
#     mean: 519.15012145749
#     std: 441.4880753791858
#     variance: 194911.72070201763
#     skewness: 0.30823031165686915
#     kurtosis: -1.1412074482365704
#     whisker_top: 1449.99
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: PRICE5
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1449.99
#     count: 26321.0
#     missing_count: 26261.0
#     not_missing_count: 60.0
#     percent_missing: 0.9977204513506326
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 22
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 549.99
#           75%: 949.99
#           95%: 1349.99
#           99%: 1439.9899999999998
#         99.9%: 1449.99
#
#     mean: 535.2905
#     std: 500.9808103886933
#     variance: 250981.7723777119
#     skewness: 0.3328805918383362
#     kurtosis: -1.3874184856975091
#     whisker_top: 1449.99
#     whisker_bottom: 0.0
#
# ColumnProfile:
#     column_name: HOUR_OF_DAY
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 23.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 24
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 13.292610477367981
#           50%: 17.0
#           75%: 20.0
#           95%: 23.0
#           99%: 23.0
#         99.9%: 23.0
#
#     mean: 15.06622088826411
#     std: 7.10246215975062
#     variance: 50.444968730689446
#     skewness: -1.0791732553087043
#     kurtosis: -0.125853471721606
#     whisker_top: 23.0
#     whisker_bottom: 3.8515625000000013
#
# ColumnProfile:
#     column_name: label
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 2.0
#     count: 26321.0
#     missing_count: 0.0
#     not_missing_count: 26321.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 3
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 2.0
#           99%: 2.0
#         99.9%: 2.0
#
#     mean: 0.3172371870369684
#     std: 0.625419904179685
#     variance: 0.39115005654412627
#     skewness: 1.785020820185068
#     kurtosis: 1.8273128037968887
#     whisker_top: 0.0
#     whisker_bottom: 0.0

# %%
X_df = train_dflow.drop_columns(columns=['label'])
y_df = train_dflow.keep_columns(columns=['label'], validate_column_exists=True)
X_test_df = test_dflow.drop_columns(columns=['label'])
y_test_df = test_dflow.keep_columns(columns=['label'], validate_column_exists=True)

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget

cts = ws.compute_targets
amlcompute_cluster_name = "XM-Heavy-Load"
compute_target = cts[amlcompute_cluster_name]



found = False

# # Check if this compute target already exists in the workspace.

cts = ws.compute_targets
if amlcompute_cluster_name in cts and cts[amlcompute_cluster_name].type == 'AmlCompute':
    found = True
    print('Found existing compute target.')
    compute_target = cts[amlcompute_cluster_name]

if not found:
    print('Creating a new compute target...')
    provisioning_config = AmlCompute.provisioning_configuration(vm_size = "STANDARD_D2_V2", # for GPU, use "STANDARD_NC6"
                                                                vm_priority = 'lowpriority',
                                                                min_nodes = 0, max_nodes = 6)

    # Create the cluster.\n",
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, provisioning_config)

#     # Can poll for a minimum number of nodes and for a specific timeout.
#     # If no min_node_count is provided, it will use the scale settings for the cluster.
#     compute_target.wait_for_completion(show_output = True, min_node_count = None, timeout_in_minutes = 20)

#      # For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing compute target.

# %%
from azureml.core.runconfig import RunConfiguration
from azureml.core.conda_dependencies import CondaDependencies
import pkg_resources

# create a new RunConfig object
conda_run_config = RunConfiguration(framework="python")

# Set compute target to AmlCompute
conda_run_config.target = compute_target
conda_run_config.environment.docker.enabled = True
conda_run_config.environment.docker.base_image = azureml.core.runconfig.DEFAULT_CPU_IMAGE

# dprep_dependency = 'azureml-dataprep==' + pkg_resources.get_distribution("azureml-dataprep").version

cd = CondaDependencies.create(pip_packages=['azureml-sdk[automl]', 'psutil'], conda_packages=['numpy','py-xgboost<=0.80'])
# cd = CondaDependencies.create(pip_packages=['azureml-sdk[automl]', dprep_dependency], conda_packages=['numpy','py-xgboost<=0.80'])
conda_run_config.environment.python.conda_dependencies = cd

# %%
# Dump X and Y to CSVs.
X_df.to_pandas_dataframe().to_csv('data/risk/X_train.csv', index=False)
y_df.to_pandas_dataframe().to_csv('data/risk/Y_train.csv', index=False)

# Dump X and Y to CSVs.
X_test_df.to_pandas_dataframe().to_csv('data/risk/X_test.csv', index=False)
y_test_df.to_pandas_dataframe().to_csv('data/risk/Y_test.csv', index=False)

# %%
ds = ws.get_default_datastore()
ds.upload(src_dir='./data/risk', target_path='data/risk', overwrite=True, show_progress=True)
# Out:
# Uploading an estimated of 4 files
# Uploading ./data/risk/X_test.csv
# Uploading ./data/risk/X_train.csv
# Uploading ./data/risk/Y_test.csv
# Uploading ./data/risk/Y_train.csv
# Uploaded ./data/risk/Y_test.csv, 1 files out of an estimated total of 4
# Uploaded ./data/risk/Y_train.csv, 2 files out of an estimated total of 4
# Uploaded ./data/risk/X_test.csv, 3 files out of an estimated total of 4
# Uploaded ./data/risk/X_train.csv, 4 files out of an estimated total of 4
# Uploaded 4 files
# $AZUREML_DATAREFERENCE_98b994b7e5f346b2b228730b04ad0186

# %%
X = Dataset.Tabular.from_delimited_files(path=ds.path('data/risk/X_train.csv'))
y = Dataset.Tabular.from_delimited_files(path=ds.path('data/risk/Y_train.csv'))

X_valid = Dataset.Tabular.from_delimited_files(path=ds.path('data/risk/X_test.csv'))
y_valid = Dataset.Tabular.from_delimited_files(path=ds.path('data/risk/Y_test.csv'))

# %%
automl_config = AutoMLConfig(task = 'classification',
                             primary_metric = 'AUC_weighted',
                             debug_log='automl_errors.log',
                             path = project_folder, #For external compute
                             run_configuration=conda_run_config, #For external compute
                             preprocess=True,
                             X = X, 
                             y = y,
                             X_valid=X_valid,
                             y_valid=y_valid,
                             iteration_timeout_minutes=10,
                             experiment_timeout_minutes=200,
                             max_concurrent_iterations=10,
                             max_cores_per_iteration=4,
                             iterations=100,
                             model_explainability=True,
                             )

# %%
ws = Workspace.from_config()

experiment_name = 'fraud-classification'

experiment = Experiment(ws, experiment_name)
#local_run = experiment.submit(automl_config, show_output = True)
remote_run = experiment.submit(automl_config, show_output = True)
# Out:
# Running on remote compute: XM-Heavy-Load
# Parent Run ID: AutoML_eed976d8-f0c9-43ee-8b54-c1d471bdc422
# Current status: FeaturesGeneration. Generating features for the dataset.
# Current status: DatasetFeaturizationCompleted. Completed featurizing the dataset.
# Current status: ModelSelection. Beginning model selection.
#
# ****************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ****************************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          7   StandardScalerWrapper ExtremeRandomTrees       0:04:05       0.8285    0.8285
#          3   MaxAbsScaler RandomForest                      0:04:36       0.8487    0.8487
#          9   MaxAbsScaler LightGBM                          0:05:05       0.9337    0.9337
#          6   MaxAbsScaler SGD                               0:05:00       0.8919    0.9337
#          0   MaxAbsScaler LightGBM                          0:05:04       0.9234    0.9337
#          8   MaxAbsScaler RandomForest                      0:05:09       0.8437    0.9337
#          1   MaxAbsScaler SGD                               0:05:09       0.8886    0.9337
#          2   StandardScalerWrapper LightGBM                 0:05:41       0.9246    0.9337
#          5   MaxAbsScaler ExtremeRandomTrees                0:07:51       0.8124    0.9337
#          4   MaxAbsScaler SGD                               0:08:28       0.8843    0.9337
#         11   MaxAbsScaler SGD                               0:07:47       0.8233    0.9337
#         13   MaxAbsScaler ExtremeRandomTrees                0:07:30       0.8381    0.9337
#         10   MaxAbsScaler BernoulliNaiveBayes               0:08:28       0.8428    0.9337
#         16   MaxAbsScaler LightGBM                          0:07:38       0.9383    0.9383
#         12   MaxAbsScaler LightGBM                          0:07:47       0.9432    0.9432
#         14   MaxAbsScaler ExtremeRandomTrees                0:07:58       0.8844    0.9432
#         15   MaxAbsScaler SGD                               0:08:08       0.8931    0.9432
#         18   MaxAbsScaler RandomForest                      0:08:30       0.7496    0.9432
#         17   StandardScalerWrapper BernoulliNaiveBayes      0:10:37       0.8223    0.9432
#         19   MaxAbsScaler LightGBM                          0:09:07       0.9520    0.9520
#         22   MaxAbsScaler LightGBM                          0:08:16       0.9530    0.9530
#         20   MaxAbsScaler LightGBM                          0:08:41       0.9496    0.9530
#         25   StandardScalerWrapper LightGBM                 0:08:07       0.9510    0.9530
#         24   StandardScalerWrapper LightGBM                 0:08:38       0.9532    0.9532
#         23   MaxAbsScaler LightGBM                          0:08:39       0.9480    0.9532
#         21   MaxAbsScaler LightGBM                          0:08:48       0.9514    0.9532
#         26   MaxAbsScaler LightGBM                          0:08:53       0.9271    0.9532
#         27   MaxAbsScaler LightGBM                          0:07:56       0.9467    0.9532
#         28   MaxAbsScaler LightGBM                          0:09:38       0.9512    0.9532
#         29   MaxAbsScaler LightGBM                          0:08:57       0.9485    0.9532
#         30   MaxAbsScaler LightGBM                          0:08:15       0.9494    0.9532
#         31   StandardScalerWrapper LightGBM                 0:08:29       0.9507    0.9532
#         35   StandardScalerWrapper LightGBM                 0:08:36       0.9503    0.9532
#         34   TruncatedSVDWrapper LightGBM                   0:09:08       0.9327    0.9532
#         32   MaxAbsScaler LightGBM                          0:09:08       0.9498    0.9532
#         33   MaxAbsScaler LightGBM                          0:09:29       0.9501    0.9532
#         36   TruncatedSVDWrapper LightGBM                   0:10:01       0.9323    0.9532
#         37   StandardScalerWrapper LightGBM                 0:08:37       0.9481    0.9532
#         38   MaxAbsScaler LightGBM                          0:09:16       0.9476    0.9532
#         39   StandardScalerWrapper LightGBM                 0:09:49       0.9449    0.9532
#         40   MaxAbsScaler LightGBM                          0:07:39       0.8784    0.9532
#         41   TruncatedSVDWrapper LightGBM                   0:08:15       0.9252    0.9532
#         44   TruncatedSVDWrapper BernoulliNaiveBayes        0:07:56       0.8409    0.9532
#         42   TruncatedSVDWrapper LightGBM                   0:08:36       0.9225    0.9532
#         45   TruncatedSVDWrapper LightGBM                   0:08:29       0.8759    0.9532
#         43   SparseNormalizer GradientBoosting              0:10:03       0.8750    0.9532
#         47   TruncatedSVDWrapper LightGBM                   0:08:38       0.9263    0.9532
#         46   MaxAbsScaler LightGBM                          0:09:19       0.9525    0.9532
#         48   TruncatedSVDWrapper LightGBM                   0:08:58       0.9290    0.9532
#         49   TruncatedSVDWrapper LightGBM                   0:08:59       0.8518    0.9532
#         50   SparseNormalizer LightGBM                      0:08:18       0.8930    0.9532
#         51   MaxAbsScaler LightGBM                          0:08:07       0.9480    0.9532
#         52   MaxAbsScaler LightGBM                          0:07:51       0.9368    0.9532
#         53   StandardScalerWrapper LightGBM                 0:08:05       0.9423    0.9532
#         55   MaxAbsScaler LightGBM                          0:08:40       0.9389    0.9532
#         54   MaxAbsScaler LightGBM                          0:10:00       0.9524    0.9532
#         56   MaxAbsScaler LightGBM                          0:08:24       0.9412    0.9532
#         57   StandardScalerWrapper LightGBM                 0:08:59       0.9476    0.9532
#         58   MaxAbsScaler LightGBM                          0:09:38       0.9519    0.9532
#         59   MaxAbsScaler LightGBM                          0:08:58       0.9513    0.9532
#         61   StandardScalerWrapper LightGBM                 0:08:43       0.9431    0.9532
#         60   StandardScalerWrapper LightGBM                 0:09:16       0.9526    0.9532
#         62   MaxAbsScaler LightGBM                          0:08:44       0.9510    0.9532
#         63   MaxAbsScaler LightGBM                          0:08:44       0.9472    0.9532
#         65   MaxAbsScaler LightGBM                          0:08:25       0.9111    0.9532
#         64   MaxAbsScaler LightGBM                          0:08:48       0.9231    0.9532
#         66   StandardScalerWrapper LightGBM                 0:08:44       0.9486    0.9532
#         67   MaxAbsScaler LightGBM                          0:08:28       0.9164    0.9532
#         70   MaxAbsScaler LightGBM                          0:07:24       0.8851    0.9532
#         68   MaxAbsScaler LightGBM                          0:08:25       0.9356    0.9532
#         72   StandardScalerWrapper LightGBM                 0:07:22       0.9180    0.9532
#         71   MaxAbsScaler LightGBM                          0:07:56       0.9360    0.9532
#         69   StandardScalerWrapper LightGBM                 0:08:44       0.9500    0.9532
#         73   StandardScalerWrapper LightGBM                 0:07:49       0.8978    0.9532
#         74   MaxAbsScaler LightGBM                          0:07:48       0.9347    0.9532
#         75   StandardScalerWrapper LightGBM                 0:08:37       0.9410    0.9532
#         76   MaxAbsScaler LightGBM                          0:09:05       0.9498    0.9532
#         77   MaxAbsScaler LightGBM                          0:08:39       0.9514    0.9532
#         79   MaxAbsScaler LightGBM                          0:07:42       0.9338    0.9532
#         78   MaxAbsScaler LightGBM                          0:08:16       0.9501    0.9532
#         81   StandardScalerWrapper LightGBM                 0:08:26       0.9488    0.9532
#         80   StandardScalerWrapper LightGBM                 0:08:45       0.9417    0.9532
#         82   MaxAbsScaler LightGBM                          0:08:25       0.9497    0.9532
#         84   MaxAbsScaler LightGBM                          0:06:17       0.9385    0.9532
#         83   MaxAbsScaler LightGBM                          0:09:05       0.9440    0.9532
#         85   TruncatedSVDWrapper LightGBM                   0:06:06       0.8488    0.9532
#         86   MaxAbsScaler LightGBM                          0:06:25       0.9527    0.9532
#         87   MaxAbsScaler LightGBM                          0:06:57       0.9501    0.9532
#         89   StandardScalerWrapper RandomForest             0:05:03       0.9353    0.9532
#         88   MaxAbsScaler LightGBM                          0:05:44       0.9453    0.9532
#         90   TruncatedSVDWrapper LightGBM                   0:05:09       0.8800    0.9532
#         92   MaxAbsScaler LightGBM                          0:05:08       0.9457    0.9532
#         91   MaxAbsScaler LightGBM                          0:05:44       0.9527    0.9532
#         93   StandardScalerWrapper LightGBM                 0:05:43       0.9498    0.9532
#         94   MaxAbsScaler LightGBM                          0:06:31       0.9488    0.9532
#         96   MaxAbsScaler LightGBM                          0:04:49       0.9175    0.9532
#         95   StandardScalerWrapper LightGBM                 0:07:04       0.9418    0.9532
#         97   MaxAbsScaler LightGBM                          0:05:37       0.9501    0.9532
#         98    VotingEnsemble                                0:07:36       0.9552    0.9552
#         99    StackEnsemble                                 0:09:03       0.9566    0.9566

# %%
from azureml.widgets import RunDetails
RunDetails(remote_run).show()
# Out:
# A Jupyter Widget

# %%
# print(remote_run.get_output())
best_run, fitted_model = remote_run.get_output()
print(best_run)
print(fitted_model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-247-757614b8e513> in <module>()
#       1 # print(remote_run.get_output())
# ----> 2 best_run, fitted_model = remote_run.get_output()
#       3 print(best_run)
#       4 print(fitted_model)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/train/automl/run.py in get_output(self, iteration, metric, return_onnx_model)
#     551         else:
#     552             with open(model_local, "rb") as model_file:
# --> 553                 fitted_model = pickle.load(model_file)
#     554         return curr_run, fitted_model
#     555
#
# ModuleNotFoundError: No module named 'pandas.core.internals.managers'; 'pandas.core.internals' is not a package

# %%
from azureml.train.automl.automlexplainer import retrieve_model_explanation

shap_values, expected_values, overall_summary, overall_imp, per_class_summary, per_class_imp = \
    retrieve_model_explanation(best_run)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-6bb1883b0e63> in <module>()
#       1 from azureml.train.automl.automlexplainer import retrieve_model_explanation
#       2
# ----> 3 shap_values, expected_values, overall_summary, overall_imp, per_class_summary, per_class_imp =     retrieve_model_explanation(best_run)
#
# NameError: name 'best_run' is not defined

# %%
print(overall_summary)
print(overall_imp)
print(per_class_summary)
print(per_class_imp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-7099a46084b0> in <module>()
# ----> 1 print(overall_summary)
#       2 print(overall_imp)
#       3 print(per_class_summary)
#       4 print(per_class_imp)
#
# NameError: name 'overall_summary' is not defined

# %%
print(shap_values)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(expected_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e9c9fe5a5a1> in <module>()
# ----> 1 print(expected_values)
#
# NameError: name 'expected_values' is not defined
