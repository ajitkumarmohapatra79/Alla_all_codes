# %% [markdown]
# ### Install dependencies

# %%
# !pip install azureml-sdk
# !pip install azureml-train-automl
# !pip install pandas
# !pip install seaborn

# %% [markdown]
# ### Declare constants

# %%
subscription_id = 'be564fde-136b-4709-b7b6-abfc0bdfc134'
resource_group  = 'xm-ml'
workspace_name  = 'xm-ml-workspace'
experiment_name = 'mlops-automl1'
project_folder = './contoso-aml'
cluster_name = 'fortestingnew'
aks_cluster_name = 'multiservice'
aks_service_name ='mlops-autml-s1'

# Working directory
if not os.path.exists(project_folder):
    os.makedirs(project_folder)

# %% [markdown]
# ### Import open source Python libraries

# %%
import logging
import os
import random
import re
import lightgbm
import pandas as pd
import numpy as np
import json
import csv
from datetime import datetime
now = datetime. now()
from shutil import copy2
from matplotlib import pyplot as plt
from matplotlib.pyplot import imshow
from sklearn import datasets
import seaborn as sns
sns.set(color_codes='True')

# %% [markdown]
# ### Import Azure Machine Learning Python SDK

# %%
import azureml.core
from azureml.core import Workspace
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.core.compute import AksCompute, ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.core.conda_dependencies import CondaDependencies 
from azureml.core.datastore import Datastore
from azureml.core.dataset import Dataset
import azureml.dataprep as dprep 
from azureml.core.webservice import Webservice, AksWebservice, AciWebservice
from azureml.core.image import ContainerImage, Image
from azureml.core.model import Model
from azureml.core.runconfig import DataReferenceConfiguration, RunConfiguration
from azureml.train.automl import AutoMLConfig
from azureml.train.automl.run import AutoMLRun
from azureml.widgets import RunDetails
from azureml.core.model import InferenceConfig
from azureml.data.data_reference import DataReference
from azureml.pipeline.core import Pipeline, PipelineData, PublishedPipeline, PipelineRun, Schedule, TrainingOutput
from azureml.pipeline.core.graph import PipelineParameter
from azureml.pipeline.steps import PythonScriptStep
from azureml.train.automl import AutoMLConfig, AutoMLStep
from azureml.train.automl.automlexplainer import retrieve_model_explanation

# %% [markdown]
# ### Connect to Azure Workspace

# %%
try:
    ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
    ws.write_config()
    ws = Workspace.from_config()
    print('Library configuration succeeded')
except:
    print('Workspace not found')
# Out:
# Library configuration succeeded

# %% [markdown]
# ### Create a Azure AutoML Workspace Experiment

# %%
experiment = Experiment(ws, experiment_name)

output = {}
output['SDK version'] = azureml.core.VERSION
output['Subscription ID'] = ws.subscription_id
output['Workspace'] = ws.name
output['Experiment'] = experiment.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
output['Project Directory'] = project_folder
pd.set_option('display.max_colwidth', -1)
pd.DataFrame(data=output, index=['']).T
# Out:
#
# SDK version        1.0.72
# Subscription ID    be564fde-136b-4709-b7b6-abfc0bdfc134
# Workspace          xm-ml-workspace
# Experiment         mlops-automl1
# Resource Group     xm-ml
# Location           centralus
# Project Directory  ./contoso-aml

# %% [markdown]
# ### Get DataStore and list DataSets (Azure Storage, Azure Data Lake, Azure SQL and more)

# %%
ds = ws.get_default_datastore()
for dataset in Dataset.list(ws):
    print(dataset.name)
# Out:
# WARNING - "Dataset.list" is deprecated after version 1.0.69. Please use "Dataset.get_all" to retrieve datasets registered in the workspace. See Dataset API change notice at https://aka.ms/dataset-deprecation.
# 54284082-d43_eval
# c14928e3-0dc_eval
# 5dcd29dd-0cc_eval
# 770cf3ff-eeb_eval
# 90d3f662-cdd_eval
# b4a8db01-2a2_eval
# 9ed32097-ddd_eval
# 95b75317-70f_eval
# 32983415-05c_eval
# d92d9533-982_eval
# 850e2ace-4cd_eval
# 6fa8e4cc-42f_eval
# 93c6bc50-890_eval
# 921896d7-36c_eval
# ec9286e2-0ef_eval
# e10fa5e0-6b1_eval
# 16f971c9-6b3_eval
# abfc46f6-665_eval
# 4e62cfbf-c69_eval
# dba5a979-315_eval
# ffcb04b8-276_eval
# fd9d2f63-86a_eval
# 303fd1bf-a53_eval
# bcf36388-6ca_eval
# bd0afbe0-838_eval
# f9e58ac2-694_eval
# 83ca6a75-2d9_eval
# b2a4d835-4e5_eval
# 1d4b0e40-1a6_eval
# 6668fca3-ee3_eval
# 6502d1a1-e11_eval
# f6894d97-6a2_eval
# 1b85b1c2-b85_eval
# 8d71adb2-d8c_eval
# 00d771cf-51f_eval
# 0cdf7c17-e92_eval
# dc331a5b-5db_eval
# 1efb0f5f-4cf_eval
# 039197ea-6fc_eval
# ...

# %%
#train_data = ws.datasets['vehicle_training']
#test_data = ws.datasets['vehicle_data']

#train_df = train_data.to_pandas_dataframe()
#test_df = test_data.to_pandas_dataframe()

# %%
train_df = pd.read_csv('risk_train.csv')

test_df = pd.read_csv('risk_test.csv')

#X_df = train_dflow.drop_columns(columns=['label'])
#y_df = train_dflow.keep_columns(columns=['label'], validate_column_exists=True)

#X_test_df = test_dflow.drop_columns(columns=['label'])
#y_test_df = test_dflow.keep_columns(columns=['label'], validate_column_exists=True)

train_dflow = dprep.read_csv('risk_train.csv', infer_column_types=True)

test_dflow = dprep.read_csv('risk_test.csv', infer_column_types=True)

X_df = train_dflow.drop_columns(columns=['label'])
y_df = train_dflow.keep_columns(columns=['label'], validate_column_exists=True)

X_test_df = test_dflow.drop_columns(columns=['label'])
y_test_df = test_dflow.keep_columns(columns=['label'], validate_column_exists=True)

# Dump X and Y to CSVs.
X_df.to_pandas_dataframe().to_csv('data/X_train.csv', index=False)
y_df.to_pandas_dataframe().to_csv('data/Y_train.csv', index=False)

# Dump X and Y to CSVs.
X_test_df.to_pandas_dataframe().to_csv('data/X_test.csv', index=False)
y_test_df.to_pandas_dataframe().to_csv('data/Y_test.csv', index=False)

ds = ws.get_default_datastore()
ds.upload(src_dir='./data', target_path='data/', overwrite=True, show_progress=True)


X = Dataset.Tabular.from_delimited_files(path=ds.path('data/X_train.csv'))
y = Dataset.Tabular.from_delimited_files(path=ds.path('data/Y_train.csv'))

X_valid = Dataset.Tabular.from_delimited_files(path=ds.path('data/X_test.csv'))
y_valid = Dataset.Tabular.from_delimited_files(path=ds.path('data/Y_test.csv'))
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Uploading an estimated of 5 files
# Uploading ./data/X_test.csv
# Uploading ./data/X_train.csv
# Uploading ./data/Y_test.csv
# Uploading ./data/Y_train.csv
# Uploading ./data/env_dependencies.json
# Uploaded ./data/Y_test.csv, 1 files out of an estimated total of 5
# Uploaded ./data/env_dependencies.json, 2 files out of an estimated total of 5
# Uploaded ./data/Y_train.csv, 3 files out of an estimated total of 5
# Uploaded ./data/X_test.csv, 4 files out of an estimated total of 5
# Uploaded ./data/X_train.csv, 5 files out of an estimated total of 5
# Uploaded 5 files
#    TOTAL_PRICE  THIRD_PARTY_ID_SCORE IS_EXISTING_CUSTOMER  NUM_PORTIN  \
# 0 586.98        323                   Y                    0
# ...

# %%
#ds = ws.get_default_datastore()
#ds.upload(src_dir='./data', target_path='data/', overwrite=True, show_progress=True)
datastores = ws.datastores
for name, datastore in datastores.items():
    print(name,  datastore.datastore_type)
# Out:
# workspacefilestore AzureFile
# workspaceblobstore AzureBlob
# xmmlworkspace1057983396__azureml_blobstore_001ed240_0454_4ad3_a17e_78266be63d2e AzureBlob

# %%
train_df.columns
# Out:
# Index(['TOTAL_PRICE', 'THIRD_PARTY_ID_SCORE', 'IS_EXISTING_CUSTOMER',
#        'NUM_PORTIN', 'FIRST_PARTY_ID_SCORE', 'ONETIMECHARGE',
#        'INSTALLMENT_AMOUNT', 'DEVICE_AT_HOME', 'FRAUDNET_SCORE', 'NUM_BYOD',
#        'IDA_RESULT', 'ALLOWED_LINES', 'MONTHLYRECURRINGCHARGE',
#        'EXTERNAL_CREDIT_CHECK_DONE', 'SALES_CHANNEL',
#        'EXTERNAL_APPROVED_LINES', 'APPROVED_LINES', 'ACNT_BILL_LNAME_MATCHES',
#        'ACNT_SHIP_FNAME_MATCHES', 'ACNT_SHIP_LNAME_MATCHES',
#        'SHIP_BILL_FNAME_MATCHES', 'BILL_SHIP_ADDR_MATCHES', 'MAKE1', 'MAKE2',
#        'MAKE3', 'MAKE4', 'MAKE5', 'MODEL1', 'MODEL2', 'MODEL3', 'MODEL4',
#        'MODEL5', 'PRICE1', 'PRICE2', 'PRICE3', 'PRICE4', 'PRICE5',
#        'HOUR_OF_DAY', 'label'],
#       dtype='object')

# %% [markdown]
# ### Explore the training data

# %%
col_list = ['TOTAL_PRICE']
df = train_df[col_list]
sns.distplot(df)

# %%
col_list = train_df.columns
df = train_df[col_list[1:6]]
#sns.pairplot(df)

# %% [markdown]
# ### Create get_data.py for Automate Machine Learning to use training dataset

# %%
# %%writefile $project_folder/get_data.py
import pandas as pd
import numpy as np
from azureml.core import Workspace, Datastore, Dataset, Run

def get_data():
    run = Run.get_context()
    workspace = run.experiment.workspace
    dataset = Dataset.get(workspace=workspace, name='vehicle_training')
    
    # Get dataset by name
    train_data = dataset.to_pandas_dataframe()
    
    X = train_data.iloc[:,1:19]
    Y = train_data.iloc[:,-1].values

    return { "X" : X.values, "y" : Y.flatten() }

# %% [markdown]
# # Create AML Compute Cluster

# %%
try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D12_V2', max_nodes=4)

    # create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True)
# Out:
# Found existing compute target.

# %% [markdown]
# <img src='../mlsolutions/workplacesafety/resources/compute.png'/>

# %% [markdown]
# ### Setup Automated Machine Learning Experiment

# %% [markdown]
# <img align="left" width="850" src="https://raw.githubusercontent.com/chrislauren/amlallhands/master/automl%20overview.png">

# %%
run_config = RunConfiguration(framework="python")
run_config.target = compute_target
run_config.environment.docker.enabled = True

automl_config = AutoMLConfig(task = 'classification',
                             primary_metric = 'AUC_weighted',
                             debug_log='automl_errors.log',
                             path = project_folder, #For external compute
                             run_configuration=run_config, #For external compute
                             preprocess=True,
                             X = X, 
                             y = y,
                             X_valid=X_valid,
                             y_valid=y_valid,
                             iteration_timeout_minutes=10,
                             experiment_timeout_minutes=200,
                             max_concurrent_iterations=10,
                             max_cores_per_iteration=4,
                             iterations=100,
                             model_explainability=True,
                             )
# Out:
# WARNING - The AutoMLConfig inputs you have specified will soon be deprecated. Please use the AutoMLConfig shown in our documentation: https://aka.ms/AutoMLConfig

# %% [markdown]
# ### Run our Experiment on AML Compute

# %%
remote_run = experiment.submit(automl_config, show_output=True)
# Out:
# Running on remote or ADB.
# Running on remote compute: fortestingnew
# Parent Run ID: AutoML_55c400c3-166b-46fa-9d72-ac6503b01ce1
#
# Current status: FeaturesGeneration. Generating features for the dataset.
# Current status: DatasetFeaturizationCompleted. Completed featurizing the dataset.
# Current status: ModelSelection. Beginning model selection.
#
# ****************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ****************************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
# ...

# %% [markdown]
# ### Display Automated ML Run Details

# %%
remote_run
# Out:
# Run(Experiment: mlops-automl1,
# Id: AutoML_55c400c3-166b-46fa-9d72-ac6503b01ce1,
# Type: automl,
# Status: Completed)

# %%
from azureml.telemetry import set_diagnostics_collection
set_diagnostics_collection(send_diagnostics = True)
# Out:
# Turning diagnostics collection on.

# %%
RunDetails(remote_run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': True, 'log_level': 'INFO', 's…

# %%
best_run, fitted_model = remote_run.get_output()
best_run_metrics = best_run.get_metrics()
parameter_values = best_run.get_details() ['runDefinition']['arguments']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-207-9b3e7351195b> in <module>
# ----> 1 best_run, fitted_model = remote_run.get_output()
#       2 best_run_metrics = best_run.get_metrics()
#       3 parameter_values = best_run.get_details() ['runDefinition']['arguments']
#
# AttributeError: 'Run' object has no attribute 'get_output'

# %%
print('Best Run Id: ', best_run.id)
# Out:
# Best Run Id:  AutoML_55c400c3-166b-46fa-9d72-ac6503b01ce1_99

# %%
#print('Best Run Id: ', best_run.id)
remote_run =  experiment.start_logging()

AUC_weighted_Max= best_run_metrics['AUC_weighted']
remote_run.log('AUC_weighted_Max',AUC_weighted_Max)
remote_run.complete()

# %%
import azureml.widgets
from azureml.widgets import RunDetails
RunDetails(best_run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': True, 'log_level': 'INFO', 's…

# %%
from azureml.widgets import RunDetails
from azureml.core.run import Run

experiment = Experiment (ws, 'mlops-automl1')
run_id = 'AutoML_55c400c3-166b-46fa-9d72-ac6503b01ce1_99' #replace with run_ID
run = Run(experiment, run_id)
RunDetails(run).show(True)
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': True, 'log_level': 'INFO', 's…

# %% [markdown]
# ### Show best run and model

# %%
best_run, fitted_model = remote_run.get_output()
print(best_run)
# Out:
# Run(Experiment: mlops-automl1,
# Id: AutoML_55c400c3-166b-46fa-9d72-ac6503b01ce1_99,
# Type: azureml.scriptrun,
# Status: Completed)

# %% [markdown]
# ### Publish best model to Azure Machine Learning Model Registry

# %%
# register the model for deployment
model = best_run.register_model(model_name='mlopsclassifier', 
                                model_path='outputs/model.pkl', 
                                tags = {'area': "auto", 'type': "regression"}) 
print("Model name: " + model.name, "Model version: " + str(model.version), sep="\n")
# Out:
# Model name: mlopsclassifier
# Model version: 1

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# mlopsclassifier version: 1
# 	 area : auto
# 	 type : regression
#
#
# model.pkl version: 14
# 	 area : f
# 	 type : classification
#
#
# AutoML6499fe6c1best version: 1
#
#
# AutoML2c5f92f56best version: 1
#
#
# AutoML2b84a4844best version: 1
#
#
# AutoML4e33350f5best version: 1
#
#
# model.pkl version: 13
# 	 area : f
# 	 type : classification
#
#
# AutoML2f110271ebest version: 1
#
#
# model.pkl version: 12
# 	 area : f
# 	 type : classification
#
#
# model.pkl version: 11
# 	 area : f
# 	 type : classification
#
#
# AutoMLe2ab1cfdebest version: 1
#
#
# AutoML60c752913best version: 1
#
#
# riskprediction version: 12
# 	 key : 1
# 	 fraud : riskpredict
#
#
# model.pkl version: 10
# 	 area : f
# 	 type : classification
#
#
# model1.pkl version: 1
# 	 area : f
# 	 type : classification
#
#
# model.pkl version: 9
# 	 area : f
# 	 type : classification
#
#
# model.pkl version: 8
#
#
# AutoML145d8f671best version: 6
#
#
# AutoML145d8f671best version: 5
#
#
# ...

# %% [markdown]
# ### Create Scoring File

# %%
# %%writefile score.py
import pickle
import json
import azureml.train.automl
import numpy as np

from azureml.core.model import Model
from inference_schema.schema_decorators import input_schema, output_schema
from inference_schema.parameter_types.numpy_parameter_type import NumpyParameterType
from sklearn.externals import joblib

#input_sample = np.array([['Centre_Val_de_Loire', 'MidWest', 18.12363, 6.041211, 4.022051, 1.0055129999999999, 250, 'M10', 'Y2013', 0.8890518, 'True', -2.081553, -7.993295, 10.80828, -12.12702, -0.6662728, -10.65882, 0.6769765999999999, -14.394279999999998, -2.4150240000000003, -7.103573, 7.1126830000000005, -6.97204, 1.0697889999999999, -17.84025, 7.2463169999999995, -20.07207, -0.3555982, -10.730080000000001, -1.621019, -9.052511, -3.151685, -12.38087, -2.213263, -8.923146000000001, 11.35322, -14.51881, 4.450673, -9.823507000000001, -2.996298, -9.121293, -0.5239272, -24.48196, -2.7362900000000003, -10.16089, -1.014979, -7.749569999999999, -1.9338509999999998, -22.129839999999998, -0.3227415, -6.803357000000001, 0.8542936, -14.50496, -0.44740240000000003, -13.992920000000002, -1.34541, -14.18944, -1.526483, -11.79697, -0.9755153, -17.62779, 3.219577, -8.458607, -0.3016018, -9.000634, 3.9828300000000003, -12.40082, 3.7529589999999997, -16.78719, 3.178833, -9.794724, 2.012089, -16.29766]])
#output_sample = np.array([0])

input_sample = np.array([[855.92,  417,  True, 0,  409, 33.33,33.33, False,  600.0,  0,  'GREEN',  True,'ONLINE', 'iPhone XR',  'NA', 'NA',  'NA',  'NA']])
output_sample = np.array([0])

def init():
    global model
    # this name is model.id of model that we want to deploy
    model_path = Model.get_model_path(model_name = 'mlopsclassifier')
    # deserialize the model file back into a sklearn model
    model = joblib.load(model_path)

@input_schema('data', NumpyParameterType(input_sample))
@output_schema(NumpyParameterType(output_sample))
def run(data):
    try:
        result = model.predict(data)
        print(result)
    except Exception as e:
        result = str(e)
        print('Exception Ocurred')
        print(e)
        return {"error": result}
    return {"result":result.tolist()}
# Out:
# Overwriting score.py

# %% [markdown]
# ### Create Environment Dependency File

# %%
myenv = CondaDependencies.create(conda_packages=['numpy','scikit-learn','pandas'],pip_packages=['azureml-core','azureml-defaults','azureml-sdk[notebooks,automl]','inference-schema'])
print(myenv.serialize_to_string())

with open("myenv.yml","w") as f:
    f.write(myenv.serialize_to_string())
# Out:
# # Conda environment specification. The dependencies defined in this file will
# # be automatically provisioned for runs with userManagedDependencies=False.
#
# # Details about the Conda environment file format:
# # https://conda.io/docs/user-guide/tasks/manage-environments.html#create-env-file-manually
#
# name: project_environment
# dependencies:
#   # The python interpreter version.
#   # Currently Azure ML only supports 3.5.2 and later.
# - python=3.6.2
#
# - pip:
#   - azureml-core==1.0.72.*
#   - azureml-defaults==1.0.72.*
#   - azureml-sdk[notebooks,automl]==1.0.72.*
#   - inference-schema
# - numpy
# - scikit-learn
# - pandas
# channels:
# - conda-forge

# %%
print(model.name, model.version)
# Out:
# mlopsclassifier 1

# %%
ws.location
# Out:
# 'centralus'

# %% [markdown]
# ### Create/connect to the Kubernetes compute cluster

# %%
# Use the default configuration (can also provide parameters to customize)
#prov_config = AksCompute.provisioning_configuration(location='centralus')

# Create the cluster
#aks_target = ComputeTarget.create(workspace = ws, 
 #                         name = aks_cluster_name, 
  #                        provisioning_configuration = prov_config)

#aks_target.wait_for_completion(True)

# %% [markdown]
# ### Deploy the model to Kubernetes

# %%
aks_config = AksWebservice.deploy_configuration()


inference_config = InferenceConfig(runtime= "python", entry_script="score.py", conda_file="myenv.yml")

deployment_config = AksWebservice.deploy_configuration(cpu_cores = 1, memory_gb = 1)

aks_target = AksCompute(ws,"multiservice")

aks_service = Model.deploy(workspace=ws,
                           name=aks_service_name,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target)

aks_service.wait_for_deployment(show_output = True)
print(aks_service.state)
# Out:
# WARNING - Warning, azureml-defaults not detected in provided environment pip dependencies. The azureml-defaults package contains requirements for the inference stack to run, and should be included.
# Running.............................................................................................
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# ### Connect to the deployed webservice

# %%
aks_service = Webservice(ws,aks_service_name)

# %%
print("The score uri:",aks_service.scoring_uri)
print("The swagger:", aks_service.swagger_uri)
primary, secondary = aks_service.get_keys()
print("the primary key:",primary)
print("the secondry key:",secondary)
# Out:
# The score uri: http://13.67.176.88:80/api/v1/service/mlops-autml-s1/score
# The swagger: http://13.67.176.88:80/api/v1/service/mlops-autml-s1/swagger.json
# the primary key: wLfjkDvX8hlEfNweBxPor3KqM0yzzQqQ
# the secondry key: TFtUBPCKDogEwSqQcJkFz7G6uy6oTTdX

# %%
import json
import csv
import requests
import pandas as pd
import numpy
# prepare the test data
sample = input_sample
sample = pd.DataFrame(data=[{"TOTAL_PRICE":869.92,"THIRD_PARTY_ID_SCORE":415,"IS_EXISTING_CUSTOMER":"Y","NUM_PORTIN":0,"FIRST_PARTY_ID_SCORE":356,"ONETIMECHARGE":33.33,"INSTALLMENT_AMOUNT":33.33,"DEVICE_AT_HOME":"Y","FRAUDNET_SCORE":200.0,"NUM_BYOD":0,"IDA_RESULT":"GREEN","EXTERNAL_CREDIT_CHECK_DONE":"Y","SALES_CHANNEL":"ONLINE","MODEL1":"iPhone XR","MODEL2":"NA","MODEL3":"NA","MODEL4":"NA","MODEL5":"NA", "Label":0}])

headers = {'Content-Type':'application/json'}

if aks_service.auth_enabled:
    headers['Authorization'] = 'Bearer '+aks_service.get_keys()[0]

#test_sample = json.dumps({'data': sample})
response = requests.post(aks_service.scoring_uri, data=sample, headers=headers)
print(response.json())

# %%
results = response.json()['result']

# %% [markdown]
# # Playing with Data

# %%
# Default datastore 
def_data_store = ws.get_default_datastore()

# Get the blob storage associated with the workspace
def_blob_store = Datastore(ws, "workspaceblobstore")

# Get file storage associated with the workspace
def_file_store = Datastore(ws, "workspacefilestore")

target_name = 'AutoMLOps_Data_{}_created_on_{}/'.format(ds.name,now.strftime("%d_%m_%Y"))

default_ds.upload_files(files=['./data/X_train.csv','./data/y_train.csv','./data/X_test.csv','./data/y_test.csv'], # Upload the data/diabetes.csv file
                       target_path=target_name, # Put it in a folder path in the datastore
                       overwrite=True, # Replace existing files of the same name
                       show_progress=True)
# Out:
# Uploading an estimated of 4 files
# Uploading ./data/X_test.csv
# Uploading ./data/X_train.csv
# Uploading ./data/y_test.csv
# Uploading ./data/y_train.csv
# Uploaded ./data/y_train.csv, 1 files out of an estimated total of 4
# Uploaded ./data/y_test.csv, 2 files out of an estimated total of 4
# Uploaded ./data/X_test.csv, 3 files out of an estimated total of 4
# Uploaded ./data/X_train.csv, 4 files out of an estimated total of 4
# Uploaded 4 files
# $AZUREML_DATAREFERENCE_6b4c2055b36b4e139dacdb6bbd4b3ed9

# %%
from azureml.core import Dataset
#Create a tabular dataset from the path on the datastore (this may take a short while)
df_train = Dataset.Tabular.from_delimited_files(path=(default_ds, 'data/X_train.csv'))
y_train_df = Dataset.Tabular.from_delimited_files(path=(default_ds, 'data/Y_train.csv'))
df_test = Dataset.Tabular.from_delimited_files(path=(default_ds, 'data/X_test.csv'))
y_test_df = Dataset.Tabular.from_delimited_files(path=(default_ds, 'data/Y_test.csv'))

# Display the first 20 rows as a Pandas dataframe
data_train.take(20).to_pandas_dataframe()
# Out:
#     TOTAL_PRICE  THIRD_PARTY_ID_SCORE  IS_EXISTING_CUSTOMER  NUM_PORTIN  \
# 0  586.98        323                   True                  0
# 1  804.13        329                   True                  0
# 2  2139.68       365                   False                 2
# 3  0.00          468                   False                 1
# 4  0.00          636                   True                  2
# 5  377.64        362                   True                  0
# 6  741.84        524                   True                  0
# 7  449.99        478                   True                  0
# 8  0.00          590                   False                 1
# 9  0.00          393                   True                  1
# 10 474.51        451                   False                 1
# 11 759.49        331                   False                 1
# 12 1097.84       411                   True                  0
# 13 1156.35       479                   False                 1
# ...

# %%
# register dataset
dataset_name1 = 'AWR Dataset - Dataset Train'
df_train = df_train.register(workspace=ws, 
                           name=dataset_name1,
                           description='fraud data',
                           tags = {'year':'2019', 'category':'Fraud-train'},
                           create_new_version=True)
                           
dataset_name2 = 'AWR Dataset - Dataset Test'
df_test = df_test.register(workspace=ws, 
                           name=dataset_name2,
                           description='fraud data',
                           tags = {'year':'2019', 'category':'Fraud-Test'},
                           create_new_version=True)

dataset_name3 = 'AWR Dataset - Label Train'
y_train_df  = y_train_df.register(workspace=ws, 
                           name=dataset_name3,
                           description='fraud data',
                           tags = {'year':'2019', 'category':'Fraud-label-train'},
                           create_new_version=True)

dataset_name4 = 'AWR Dataset - label Test'
y_test_df  = y_test_df .register(workspace=ws, 
                           name=dataset_name4,
                           description='Fraud-label-test-',
                           tags = {'year':'2019', 'category':'Fraud'},
                           create_new_version=True)

# %%
# List the datasets registered in the workspace
for ds in ws.datasets:
    print(ds)
# Out:
# AWR Dataset - label Train
# AWR Dataset - Test
# AWR Dataset - Label Train
# Active Watch Dataset
# 54284082-d43_eval
# c14928e3-0dc_eval
# 5dcd29dd-0cc_eval
# 770cf3ff-eeb_eval
# 90d3f662-cdd_eval
# b4a8db01-2a2_eval
# 9ed32097-ddd_eval
# 95b75317-70f_eval
# 32983415-05c_eval
# d92d9533-982_eval
# 850e2ace-4cd_eval
# 6fa8e4cc-42f_eval
# 93c6bc50-890_eval
# 921896d7-36c_eval
# ec9286e2-0ef_eval
# e10fa5e0-6b1_eval
# 16f971c9-6b3_eval
# abfc46f6-665_eval
# 4e62cfbf-c69_eval
# dba5a979-315_eval
# ffcb04b8-276_eval
# fd9d2f63-86a_eval
# 303fd1bf-a53_eval
# bcf36388-6ca_eval
# bd0afbe0-838_eval
# f9e58ac2-694_eval
# 83ca6a75-2d9_eval
# b2a4d835-4e5_eval
# 1d4b0e40-1a6_eval
# 6668fca3-ee3_eval
# 6502d1a1-e11_eval
# f6894d97-6a2_eval
# 1b85b1c2-b85_eval
# 8d71adb2-d8c_eval
# 00d771cf-51f_eval
# 0cdf7c17-e92_eval
# dc331a5b-5db_eval
# 1efb0f5f-4cf_eval
# 039197ea-6fc_eval
# 658f99e0-d8a_eval
# 6c626b14-9de_eval
# d7df0369-59a_eval
# bc255c9d-d8f_eval
# 0df7ad47-de8_eval
# e626ac7b-b00_eval
# ...

# %%
'''
# %%writefile $experiment_folder/diabetes_training.py
# Create an experiment
experiment_name = 'diabetes_training'
experiment = Experiment(workspace = ws, name = experiment_name)

# Create a folder for the experiment files
experiment_folder = './' + experiment_name
os.makedirs(experiment_folder, exist_ok=True)

print("Experiment:", experiment.name)
'''
# Out:
# '\n%%writefile $experiment_folder/diabetes_training.py\n# Create an experiment\nexperiment_name = \'diabetes_training\'\nexperiment = Experiment(workspace = ws, name = experiment_name)\n\n# Create a folder for the experiment files\nexperiment_folder = \'./\' + experiment_name\nos.makedirs(experiment_folder, exist_ok=True)\n\nprint("Experiment:", experiment.name)\n'

# %% [markdown]
# ### Create models tailored for each model and year of car using Azure Machine Learning Pipelines

# %%
# Get the experiment run context
X = 'Active Watch Dataset'
y = 'label'
# load the diabetes dataset
print("Loading data from " + dataset_name)
awr_dataset = Dataset.get_by_name(ws,name=X).to_pandas_dataframe()
awr_dataset.head(3)
# Out:
# Loading data from Active Watch Dataset
#    TOTAL_PRICE  THIRD_PARTY_ID_SCORE  IS_EXISTING_CUSTOMER  NUM_PORTIN  \
# 0 586.98        323                   True                  0
# 1 804.13        329                   True                  0
# 2 2139.68       365                   False                 2
#
#    FIRST_PARTY_ID_SCORE  ONETIMECHARGE  INSTALLMENT_AMOUNT  DEVICE_AT_HOME  \
# 0  139                  549.99         0.00                 True
# 1  343                  31.24          31.24                True
# 2  252                  83.32          83.32                False
#
#   FRAUDNET_SCORE  NUM_BYOD     ...            MODEL2  MODEL3  MODEL4  MODEL5  \
# 0  NA             0            ...       NA           NA      NA      NA
# 1  200.0          0            ...       NA           NA      NA      NA
# 2  NA             0            ...       Galaxy S10+  NA      NA      NA
#
#   PRICE1  PRICE2  PRICE3  PRICE4  PRICE5  HOUR_OF_DAY
# ...

# %%
y= 'AWR Dataset - label Train'
# load the diabetes dataset
print("Loading data from " + y)
awr_dataset = Dataset.get_by_name(ws,name=y).to_pandas_dataframe()
awr_dataset.head(3)
# Out:
# Loading data from AWR Dataset - label Train
#    label
# 0  0
# 1  0
# 2  0

# %%
data_X = default_ds.path('Active Watch Dataset').as_download(path_on_compute='Active Watch Dataset')
data_y = default_ds.path('AWR Dataset - label Train').as_download(path_on_compute='AWR Dataset - label Train')
print(data_X, '\n', data_y  )


script_params = {
    '--data-folder': data_X,
}
# Out:
# $AZUREML_DATAREFERENCE_a1bb5d82c4c947ecb63d2e9d48891053
#  $AZUREML_DATAREFERENCE_d1e97bff19dc4996a12dbd95a7ee4a76

# %%
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--data-folder', type=str, dest='data_folder', help='data folder reference')
args = parser.parse_args()
# load the diabetes data from the data reference
# Out:
# usage: ipykernel_launcher.py [-h] [--data-folder DATA_FOLDER]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/azureuser/.local/share/jupyter/runtime/kernel-729e6833-4316-49c6-8032-edf22f6681c2.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# Re-use our experiment configuration
input_data = DataReference(datastore=ds, 
                           data_reference_name='X_train',
                           path_on_datastore='data',
                           mode='download',
                           path_on_compute='/tmp/azureml_runs',
                           overwrite=True
                          )

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metirics_data = PipelineData(name='metrics_data',datastore=ds,
                             pipeline_output_name=metrics_output_name,
                             training_output=TrainingOutput(type='Metrics'))

model_data = PipelineData(name='automl_modle__version_{}_created_on_{}'.format(model.version,now.strftime("%d_%m_%Y")),
                          datastore=ds,pipeline_output_name=best_model_output_name,
                          training_output=TrainingOutput(type='Model'))

model_data.name
# Out:
# 'automl_modle__version_3_created_on_08_11_2019'

# %%
automl_step = AutoMLStep(
    name='automl_modle__created_on_{}'.format(now.strftime("%d_%m_%Y")),
    automl_config=automl_config,
    outputs=[metirics_data, model_data],
    allow_reuse=True)

automl_step.name
# Out:
# 'automl_modle__created_on_08_11_2019'

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])
# Out:
# ---------------------------------------------------------------------------
# ConfigException                           Traceback (most recent call last)
# <ipython-input-167-f8b51f8b033c> in <module>
#       3     description="pipeline_with_automlstep",
#       4     workspace=ws,
# ----> 5     steps=[automl_step])
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/_experiment_method.py in wrapper(self, *args, **kwargs)
#      91             """
#      92             ExperimentSubmitRegistrar.register_submit_function(self.__class__, submit_function)
# ---> 93             return init_func(self, *args, **kwargs)
#      94         return wrapper
#      95     return real_decorator
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/pipeline.py in __init__(self, workspace, steps, description, default_datastore, default_source_directory, resolve_closure, _workflow_provider, _service_endpoint, **kwargs)
# ...

# %%
# iterate over models and years of cars
car_models = ['iPhone 6','iPhone 6s']
car_years = ['iPhone 6]

steps = []
current = None
ds = ws.get_default_datastore()

# Build a model for every category
for i in car_models:
    for y in car_years:
                  
        automl_config = AutoMLConfig('regression',
                                     iterations = 10,
                                     iteration_timeout_minutes = 5, 
                                     max_cores_per_iteration = 10,
                                     preprocess = True,
                                     primary_metric = 'normalized_root_mean_squared_error',
                                     n_cross_validations = 2,                                     
                                     debug_log = 'automl.log',                                   
                                     verbosity = logging.DEBUG,
                                     data_script = '{}/get_data_c_{}_{}.py'.format(project_folder, i, y),
                                     run_configuration = run_config,
                                     compute_target = compute_target,
                                     path = project_folder)

        # AutoML action
        automl_step = AutoMLStep(name='automl_module__category_{}_{}'.format(i, y),
                                 automl_config=automl_config,
                                 inputs=[input_data],
                                 outputs=[metrics_data, model_data],
                                 allow_reuse=False)

        # These are the two outputs from AutoML
        metrics_data = PipelineData(name='metrics_data_category_{}_{}'.format(i, y),
                                    datastore=ds,
                                    pipeline_output_name='metrics_output_category_{}_{}'.format(i, y),
                                    training_output=TrainingOutput(type='Metrics'))

        model_data = PipelineData(name='model_data_category_{}_{}'.format(i, y),
                                  datastore=ds,
                                  pipeline_output_name='best_model_output_category_{}_{}'.format(i, y),
                                  training_output=TrainingOutput(type='Model'))
        
        # register the model afterwards
        register_step = PythonScriptStep(name='register_category_{}_{}'.format(i, y),
                                         script_name='register.py',
                                         compute_target=compute_target,
                                         source_directory=project_folder,
                                         arguments=['--model_name', '{}_{}_battery_failure_predictor'.format(i, y), '--model_path', model_data],
                                         inputs=[model_data],
                                         # These are the two outputs from AutoML
                                         allow_reuse=False)

        # And chain them together so they run sequentially
        if current:
            automl_step.run_after(current)

        current = register_step

        steps.append(automl_step)
        steps.append(register_step)

        pipeline = Pipeline(description='Generate recommendation models',
                        workspace=ws,
                        steps=steps)

        pipeline.validate()

        # Once published, we can invoke on demand via the SDK or via a REST endpoint
        published_pipeline = pipeline.publish(name='contoso-{}_{}'.format(i, y))
        steps = []
        current = None
        
        # Submit a run for the newly created pipeline
        #published_pipeline.submit(ws, published_pipeline.name)
